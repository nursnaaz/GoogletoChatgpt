# %%
# !pip install llama_index

# %%
from llama_index import Document
from llama_index import SimpleDirectoryReader,BeautifulSoupWebReader

text_list = ["This is my first sample.",
             "This is my second sample.",
             "This is my third sample"]

# create document object
documents = [Document(text=t) for t in text_list]
print(documents)


# create document object automatically
documents = SimpleDirectoryReader("../data").load_data()
print(documents)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 2
#       1 from llama_index import Document
# ----> 2 from llama_index import SimpleDirectoryReader,BeautifulSoupWebReader
#       4 text_list = ["This is my first sample.",
#       5              "This is my second sample.",
#       6              "This is my third sample"]
#       8 # create document object
#
# ImportError: cannot import name 'BeautifulSoupWebReader' from 'llama_index' (/opt/homebrew/lib/python3.11/site-packages/llama_index/__init__.py)

# %%
from llama_index import Document
from llama_index import SimpleDirectoryReader

text_list = ["This is my first sample.",
             "This is my second sample.",
             "This is my third sample"]

# create document object
documents = [Document(text=t) for t in text_list]
print(documents)
# Out:
# [Document(id_='6f8fa876-da20-4781-9b9a-b3b33dcf928c', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='cd624bef925c57a5303745d4c726a8a7224b4a405926cbeac83ae621e12bfb22', text='This is my first sample.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='dbff7e6c-8f45-4ea6-aec1-180879f55617', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='2fd69ca802512d9f4e1638ac7abbeba9a40d015864f6b1ab4679176150a91dd4', text='This is my second sample.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='c87e5cb8-6432-4724-9219-1bc36d89fb6e', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}
# ...

# %%
documents[0]
# Out:
# Document(id_='6f8fa876-da20-4781-9b9a-b3b33dcf928c', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='cd624bef925c57a5303745d4c726a8a7224b4a405926cbeac83ae621e12bfb22', text='This is my first sample.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')

# %%
documents[1]
# Out:
# Document(id_='dbff7e6c-8f45-4ea6-aec1-180879f55617', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='2fd69ca802512d9f4e1638ac7abbeba9a40d015864f6b1ab4679176150a91dd4', text='This is my second sample.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')

# %%
documents = SimpleDirectoryReader("../data",).load_data()
# Out:
# pytorch_model.bin:  72%|#######1  | 703M/982M [00:00<?, ?B/s]
# /opt/homebrew/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]
# /opt/homebrew/lib/python3.11/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# ...

# %%
for i in documents:
    print(i)
    print("*****")
# Out:
# Doc ID: 8bc3857b-0460-46d1-aad0-0cb2e1c606d6
# Text: [WORD] Coupon status abbreviation_meaning.docx.md [WORD]
# FOP.docx.md [WORD] Name corrections.docx.md [WORD] PNR creation,
# Avialability, TD and fare rules.docx.md [WORD] Refund of a Fully
# Unused Ticket.docx.md [WORD] Sale Creation Guide.docx.md [WORD]
# Upgrades.docx.md [Word]Part-used Past Date Pricing.docx.md _Inquiry
# desk Workflow.docx.md _Oojo ...
# *****
# Doc ID: d720da94-52d3-43b2-bccb-12566f567546
# Text: Slide #0:  How Not to Procrastinate A Guide to Overcoming
# Procrastination   Slide #1:  Introduction Understanding
# Procrastination  • Procrastination defined • Common reasons for
# procrastination • Impact on productivity and mental health   Slide #2:
# Problem: Lack of Motivation • Feeling overwhelmed by tasks • Unclear
# goals • Low energy levels   ...
# *****
# Doc ID: 8ac7917d-bbc2-4bc4-b202-4dd6f6c2e306
# Text: RLAIF: Scaling Reinforcement Learning from Human Feedback with
# ...

# %%
len(documents)
# Out:
# 35

# %%
for i in documents:
    print(i.metadata['file_path'])
# Out:
# ../data/Book4(Sheet4).csv
# ../data/How_Not_to_Procrastinate_Presentation_Updated.pptx
# ../data/RLAIF- Scaling Reinforcement Learning from Human Feedback with AI Feedback.pdf
# ../data/RLAIF- Scaling Reinforcement Learning from Human Feedback with AI Feedback.pdf
# ../data/RLAIF- Scaling Reinforcement Learning from Human Feedback with AI Feedback.pdf
# ../data/RLAIF- Scaling Reinforcement Learning from Human Feedback with AI Feedback.pdf
# ../data/RLAIF- Scaling Reinforcement Learning from Human Feedback with AI Feedback.pdf
# ../data/RLAIF- Scaling Reinforcement Learning from Human Feedback with AI Feedback.pdf
# ../data/RLAIF- Scaling Reinforcement Learning from Human Feedback with AI Feedback.pdf
# ../data/RLAIF- Scaling Reinforcement Learning from Human Feedback with AI Feedback.pdf
# ../data/RLAIF- Scaling Reinforcement Learning from Human Feedback with AI Feedback.pdf
# ../data/RLAIF- Scaling Reinforcement Learning from Human Feedback with AI Feedback.pdf
# ...

# %%
documents
# Out:
# [Document(id_='8bc3857b-0460-46d1-aad0-0cb2e1c606d6', embedding=None, metadata={'file_path': '../data/Book4(Sheet4).csv', 'file_name': 'Book4(Sheet4).csv', 'file_type': 'text/csv', 'file_size': 6042, 'creation_date': '2024-07-07', 'last_modified_date': '2024-06-14', 'last_accessed_date': '2024-07-07'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, hash='4479d5a0052c4d89e2d574f18bab8d761cc34579602fe857d5076bdef2f46c16', text="[WORD] Coupon status abbreviation_meaning.docx.md\n[WORD] FOP.docx.md\n[WORD] Name corrections.docx.md\n[WORD] PNR creation, Avialability, TD and fare rules.docx.md\n[WORD] Refund of a Fully Unused Ticket.docx.md\n[WORD] Sale Creation Guide.docx.md\n[WORD] Upgrades.docx.md\n[Word]Part-used Past Date Pricing.docx.md\n_Inquiry desk Workf
# ...

# %%
from llama_index import BeautifulSoupWebReader

# Initialize the reader
reader = BeautifulSoupWebReader()

# Load data from a URL
documents = reader.load_data(["https://www.bentoml.com/blog/building-rag-with-open-source-and-custom-ai-models"])

# Check if documents are loaded correctly
print(documents)

# %%
# !pip install beautifulsoup4
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
