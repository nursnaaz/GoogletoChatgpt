# %%
# !pip install llama-index-llms-ollama
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 90.2 MB/s eta 0:00:000m eta 0:00:016m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.8/130.8 kB 10.1 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
from llama_index.llms.ollama import Ollama

# %%
pip install --upgrade llama_index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 99.4 MB/s eta 0:00:000m eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 60.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 22.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pypdf
#     Found existing installation: pypdf 3.17.4
#     Uninstalling pypdf-3.17.4:
#       Successfully uninstalled pypdf-3.17.4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.2
#     Uninstalling beautifulsoup4-4.12.2:
#       Successfully uninstalled beautifulsoup4-4.12.2
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.10.52.post2
#     Uninstalling llama-index-core-0.10.52.post2:
#       Successfully uninstalled llama-index-core-0.10.52.post2
#   Attempting uninstall: llama_index
# ...

# %%
# !pip install llama-index qdrant_client torch transformers 
# !pip install llama-index-llms-ollama
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 6.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 5.1 MB/s eta 0:00:000:00:010:00:01:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.2/412.2 kB 31.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.30.0 requires protobuf<5,>=3.20, but you have protobuf 5.27.2 which is incompatible.
# gpt-pdf-md 0.3 requires cffi==1.16.0, but you have cffi 1.15.1 which is incompatible.
# gpt-pdf-md 0.3 requires Pillow==10.1.0, but you have pillow 9.5.0 which is incompatible.
# ...

# %%
# !ollama pull mistral

# %%
from llama_index.legacy.llms.ollama import Ollama
import time

llm = Ollama(model="mistral", )

def get_response(prompt, retries=3, delay=5):
    for attempt in range(retries):
        try:
            response = llm.complete(prompt)
            return response
        except ConnectionRefusedError as e:
            print(f"Connection refused. Retrying in {delay} seconds...")
            time.sleep(delay)
    raise Exception("Failed to connect after multiple attempts")

prompt = "Who is Laurie Voss? Write in 100 words."
try:
    response = get_response(prompt)
    print(response)
except Exception as e:
    print(e)
# Out:
#  Laurie Voss, also known as "Blue", is a renowned cybersecurity and software expert. He co-founded and served as CTO of SSL/TLS certificate provider Let's Encrypt from 2014 to 2019. Prior to that, he was one of the founders of Hidden Path Entertainment, a game development studio. Voss is also known for his work on DNS administration tools such as PowerDNS and DNS Made Easy. He frequently speaks at conferences about internet security and advocates for digital privacy.
