# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
import llama_index_base_methods as lm


# Scenario 1 : Your very first llm app using llama index
# packages to install : 
    # pip install llama_index
    # pip install -U llama-index-readers-file

print("Scenario 1 :") 
lm.basic_llamaindex()

# Scenario 2 : You can't digest whole document in one go, parse it into smaller doc
print("Scenario 2 :") 
lm.parse_doc_smaller_chunks()

# Scenario 3 : You want to persist the index and then use it repeatedly without loading index again and again
print("Scenario 3 :") 
lm.store_doc_index_on_local()

# Scenario 4 : You want to use different vector stores like Chroma, MongoDB Atlas etc.. 
# packages to install :
    # pip install chromadb
    # pip install llama-index-vector-stores-chroma

print("Scenario 4 :") 
lm.use_different_vector_store()

# Scenario 5 : You want to retrieve more context while performing queries
print("Scenario 5 :") 
lm.retrieve_more_doc_context()

# Scenario 6 : You don't want to use default gpt-3.5-turbo model 
print("Scenario 6 :") 
lm.change_default_llm_model()

# Scenario 7 : You want to get the streaming response just like ChatGPT
print("Scenario 7 :") 
lm.get_response_in_stream()

# Scenario 8 : You want to use different response mode and not the default one
print("Scenario 8 :") 
lm.get_different_response_mode()

# Scenario 9 : You want a chatbot functionality 
print("Scenario 9 :") 
lm.get_chatbot_for_doc()

# Scenario 10 : You don't want to use default llm model, want to use a different one altogether
# package to install : 
    # pip install llama-index-llms-ollama
    # pip install llama-index-embeddings-huggingface
# run the model before running the python script 
    # ollama run mistral

print("Scenario 10 :") 
lm.use_another_llm_model()
# Out:
# Scenario 1 :
# The author worked on writing short stories and programming, particularly on an IBM 1401 using an early version of Fortran in 9th grade. Later on, the author transitioned to microcomputers, building one from a kit and eventually getting a TRS-80 to start programming more extensively, including writing simple games and a word processor.
# Scenario 2 :
# The author focused on writing short stories and programming, particularly working on the IBM 1401 in 9th grade using an early version of Fortran.
# Scenario 3 :
# The author worked on writing short stories and programming outside of school.
# Scenario 4 :
# The author worked on writing short stories and programming, specifically using an early version of Fortran on an IBM 1401 computer in 9th grade.
# Scenario 5 :
# The author worked on writing short stories and programming, particularly on an IBM 1401 using an early version of Fortran during 9th grade.
# Scenario 6 :
# The author spent their time writing and programming before college. They wrote short stories and tried programming on the IBM 1401, a machine used by their school district for data processing. They used an early version of Fortran to write programs. However, they found the machine puzzling and couldn't figure out much to do with it. The author also learned about the possibility of programs not terminating when one of their programs didn't.
# Scenario 7 :
# The author worked on writing short stories and programming, specifically on an IBM 1401 using an early version of Fortran in 9th grade.Scenario 8 :
# The author worked on writing short stories and programming outside of school.
# Scenario 9 :
# The author worked on writing short stories and programming outside of school while growing up.
# The author spent their time growing up working on writing short stories and programming outside of school. Writing short stories allowed them to explore their creativity and storytelling skills, while programming helped them develop problem-solving abilities and technical expertise. These activities played a significant role in shaping the author's interests and skills as they grew up.
# Scenario 10 :
# /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#  The individual mentioned in the provided context grew up working on two main things outside of school – writing short stories (which were described as having little plot and focusing more on characters with strong feelings) and programming. He started programming in 9th grade using an early version of Fortran on the IBM 1401 computer that his school district used for data processing. However, it's not explicitly stated what he did outside of these two areas during his childhood or youth.

# %%
#!pip install --upgrade llama-index
#!pip install llama-index-embeddings-ollama
# !pip install chromadb

# !pip install llama-index-vector-stores-chroma
# !pip install llama-index-embeddings-huggingface
# Out:
# Requirement already satisfied: chromadb in /opt/homebrew/lib/python3.11/site-packages (0.5.3)
# Requirement already satisfied: build>=1.0.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (1.0.3)
# Requirement already satisfied: requests>=2.28 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (2.5.2)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (0.105.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0.post1)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: posthog>=2.4.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (4.9.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (1.18.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (1.64.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (30.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (3.10.5)
# Requirement already satisfied: httpx>=0.27.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: packaging>=19.0 in /opt/homebrew/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in /opt/homebrew/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /opt/homebrew/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/homebrew/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (3.4)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /Users/m.alaudeen/Library/Python/3.11/lib/python/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/m.alaudeen/Library/Python/3.11/lib/python/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.23.4)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.1.0)
# Requirement already satisfied: coloredlogs in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (5.27.2)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.11.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.61.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (69.1.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /opt/homebrew/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /opt/homebrew/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (2.14.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/homebrew/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb) (0.23.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/homebrew/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: httptools>=0.5.0 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.2.0)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/homebrew/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/homebrew/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.0)
# Downloading protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 10.9 MB/s eta 0:00:000:00:01
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.27.2
#     Uninstalling protobuf-5.27.2:
#       Successfully uninstalled protobuf-5.27.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gpt-pdf-md 0.3 requires cffi==1.16.0, but you have cffi 1.15.1 which is incompatible.
# gpt-pdf-md 0.3 requires Pillow==10.1.0, but you have pillow 9.5.0 which is incompatible.
# gpt-pdf-md 0.3 requires protobuf==4.25.0, but you have protobuf 4.25.3 which is incompatible.
# gpt-pdf-md 0.3 requires urllib3==2.0.7, but you have urllib3 2.1.0 which is incompatible.
# mlserver 1.3.5 requires fastapi!=0.89.0,<=0.89.1,>=0.88.0, but you have fastapi 0.105.0 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.25.3 which is incompatible.
# grpcio-tools 1.64.1 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.3 which is incompatible.
# mediapipe 0.10.1 requires protobuf<4,>=3.11, but you have protobuf 4.25.3 which is incompatible.
# Successfully installed protobuf-4.25.3
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Collecting llama-index-vector-stores-chroma
#   Downloading llama_index_vector_stores_chroma-0.1.10-py3-none-any.whl.metadata (705 bytes)
# Requirement already satisfied: chromadb<0.6.0,>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-vector-stores-chroma) (0.5.3)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-vector-stores-chroma) (0.10.52.post1)
# Requirement already satisfied: build>=1.0.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.0.3)
# Requirement already satisfied: requests>=2.28 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (2.5.2)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.105.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.24.0.post1)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.25.0)
# Requirement already satisfied: posthog>=2.4.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (4.9.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.18.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (7.4.0)
# Requirement already satisfied: importlib-resources in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.64.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (30.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (3.10.5)
# Requirement already satisfied: httpx>=0.27.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.27.0)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/homebrew/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (3.9.1)
# Requirement already satisfied: dataclasses-json in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (0.6.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (2024.2.0)
# Requirement already satisfied: llama-cloud<0.0.7,>=0.0.6 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (0.0.6)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/m.alaudeen/Library/Python/3.11/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (1.5.8)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (3.8.1)
# Requirement already satisfied: openai>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (1.35.7)
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (9.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (0.7.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (0.9.0)
# Requirement already satisfied: wrapt in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (1.3.1)
# Requirement already satisfied: packaging>=19.0 in /opt/homebrew/lib/python3.11/site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (23.2)
# Requirement already satisfied: pyproject_hooks in /opt/homebrew/lib/python3.11/site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.0.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /opt/homebrew/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/homebrew/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.27.0)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.0.2)
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (3.4)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /Users/m.alaudeen/Library/Python/3.11/lib/python/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/m.alaudeen/Library/Python/3.11/lib/python/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (2.23.4)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.4.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (2.1.0)
# Requirement already satisfied: click in /opt/homebrew/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (2023.12.25)
# Requirement already satisfied: coloredlogs in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (23.5.26)
# Requirement already satisfied: protobuf in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (4.25.3)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.12)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (1.8.0)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (6.11.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.61.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (69.1.0)
# Requirement already satisfied: asgiref~=3.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /opt/homebrew/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic>=1.9->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /opt/homebrew/lib/python3.11/site-packages (from pydantic>=1.9->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (2.14.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.28->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/homebrew/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (3.0.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/homebrew/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.0.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (12.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (3.20.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-chroma) (2023.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (4.9)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (3.13.1)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (3.17.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/homebrew/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/homebrew/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->llama-index-vector-stores-chroma) (0.5.0)
# Downloading llama_index_vector_stores_chroma-0.1.10-py3-none-any.whl (5.0 kB)
# Installing collected packages: llama-index-vector-stores-chroma
# Successfully installed llama-index-vector-stores-chroma-0.1.10
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Requirement already satisfied: llama-index-embeddings-huggingface in /opt/homebrew/lib/python3.11/site-packages (0.2.2)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.23.4)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-embeddings-huggingface) (0.10.52.post1)
# Requirement already satisfied: sentence-transformers>=2.6.1 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-embeddings-huggingface) (3.0.1)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.2.0)
# Requirement already satisfied: packaging>=20.9 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.1)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.9.0)
# Requirement already satisfied: aiohttp in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.9.1)
# Requirement already satisfied: minijinja>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/homebrew/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.0.25)
# Requirement already satisfied: dataclasses-json in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.6.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: httpx in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.27.0)
# Requirement already satisfied: llama-cloud<0.0.7,>=0.0.6 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.0.6)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/m.alaudeen/Library/Python/3.11/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.5.8)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.25.0)
# Requirement already satisfied: openai>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.35.7)
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (9.5.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /opt/homebrew/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /opt/homebrew/lib/python3.11/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.41.2)
# Requirement already satisfied: torch>=1.11.0 in /opt/homebrew/lib/python3.11/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.1.2)
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.11/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.2.2)
# Requirement already satisfied: scipy in /opt/homebrew/lib/python3.11/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.11.4)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: pydantic>=1.10 in /opt/homebrew/lib/python3.11/site-packages (from llama-cloud<0.0.7,>=0.0.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.5.2)
# Requirement already satisfied: anyio in /opt/homebrew/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.7.1)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.2)
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.4)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: click in /opt/homebrew/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (8.1.7)
# Requirement already satisfied: joblib in /opt/homebrew/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/homebrew/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.0.2)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.12)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.1.2)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/homebrew/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.4.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/m.alaudeen/Library/Python/3.11/lib/python/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic>=1.10->llama-cloud<0.0.7,>=0.0.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /opt/homebrew/lib/python3.11/site-packages (from pydantic>=1.10->llama-cloud<0.0.7,>=0.0.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.14.5)
# Requirement already satisfied: six>=1.5 in /Users/m.alaudeen/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
from llama_index import SimpleDirectoryReader, VectorStoreIndex
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from llama_index import SimpleDirectoryReader, VectorStoreIndex
#
# ImportError: cannot import name 'SimpleDirectoryReader' from 'llama_index' (unknown location)

# %%
pip install --upgrade llama_index

# %%
# !pip uninstall --yes -r uninstall.txt
# Out:
# WARNING: Skipping llma_index as it is not installed.
# WARNING: Skipping llama-index-agent-openai as it is not installed.
# WARNING: Skipping llama-index-cli as it is not installed.
# WARNING: Skipping llama-index-core as it is not installed.
# WARNING: Skipping llama-index-embeddings-ollama as it is not installed.
# WARNING: Skipping llama-index-embeddings-openai as it is not installed.
# WARNING: Skipping llama-index-indices-managed-llama-cloud as it is not installed.
# WARNING: Skipping llama-index-legacy as it is not installed.
# WARNING: Skipping llama-index-llms-ollama as it is not installed.
# WARNING: Skipping llama-index-llms-openai as it is not installed.
# WARNING: Skipping llama-index-multi-modal-llms-openai as it is not installed.
# WARNING: Skipping llama-index-program-openai as it is not installed.
# WARNING: Skipping llama-index-question-gen-openai as it is not installed.
# WARNING: Skipping llama-index-readers-file as it is not installed.
# WARNING: Skipping llama-index-readers-llama-parse as it is not installed.
# WARNING: Skipping llama-parse as it is not installed.
# WARNING: Skipping llama-cloud as it is not installed.

# %%
# !pip show llama_index
# Out:
# WARNING: Package(s) not found: llama_index

# %%
# !pip cache purge
# Out:
# WARNING: No matching packages
# Files removed: 0

# %%
pip list
# Out:
# Package                                  Version
# ---------------------------------------- ---------------
# absl-py                                  1.4.0
# accelerate                               0.25.0
# afinn                                    0.1
# aiofiles                                 23.2.1
# aiohttp                                  3.9.1
# aiokafka                                 0.10.0
# aiosignal                                1.3.1
# alembic                                  1.8.1
# altair                                   5.2.0
# annotated-types                          0.6.0
# anthropic                                0.30.1
# anyascii                                 0.3.2
# anyio                                    3.7.1
# appnope                                  0.1.3
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.3.0
# asgiref                                  3.8.1
# aspose-words                             23.12.0
# asttokens                                2.4.1
# astunparse                               1.6.3
# async-lru                                2.0.4
# async-timeout                            4.0.3
# attrs                                    23.1.0
# azure-common                             1.1.28
# azure-core                               1.29.6
# azure-mgmt-core                          1.4.0
# azure-mgmt-resource                      23.0.1
# Babel                                    2.14.0
# backoff                                  2.2.1
# bcrypt                                   4.0.1
# beautifulsoup4                           4.12.3
# bleach                                   6.1.0
# blinker                                  1.7.0
# blis                                     0.7.11
# boto3                                    1.34.2
# botocore                                 1.34.2
# Brotli                                   1.1.0
# build                                    1.0.3
# CacheControl                             0.13.1
# cachetools                               5.3.2
# catalogue                                2.0.10
# certifi                                  2023.7.22
# cffi                                     1.15.1
# cfscrape                                 2.1.1
# charset-normalizer                       3.3.2
# chroma-hnswlib                           0.7.3
# chromadb                                 0.5.3
# cleo                                     2.1.0
# click                                    8.1.7
# click-params                             0.3.0
# cloudpathlib                             0.16.0
# cloudpickle                              2.2.1
# cobble                                   0.1.3
# coloredlogs                              15.0.1
# comm                                     0.2.0
# confection                               0.1.4
# ConfigArgParse                           1.7
# contourpy                                1.1.0
# contractions                             0.1.73
# crashtest                                0.4.1
# cryptography                             41.0.5
# cycler                                   0.11.0
# cymem                                    2.0.8
# Cython                                   3.0.10
# databricks-cli                           0.18.0
# dataclasses-json                         0.6.3
# datasets                                 2.16.1
# debugpy                                  1.8.0
# decorator                                5.1.1
# defusedxml                               0.7.1
# Deprecated                               1.2.14
# diffusers                                0.27.2
# dill                                     0.3.7
# dirtyjson                                1.0.8
# diskcache                                5.6.3
# distlib                                  0.3.8
# distro                                   1.8.0
# dm-tree                                  0.1.8
# docker                                   6.1.3
# docopt                                   0.6.2
# docx2txt                                 0.8
# duckduckgo_search                        6.1.7
# dulwich                                  0.21.7
# en-core-web-sm                           3.7.1
# entrypoints                              0.4
# et-xmlfile                               1.1.0
# etils                                    1.7.0
# evaluate                                 0.4.1
# executing                                2.0.1
# fastapi                                  0.105.0
# fastapi-utils                            0.2.1
# fastjsonschema                           2.19.0
# fasttext                                 0.9.2
# filelock                                 3.13.1
# Flask                                    2.3.3
# Flask-BasicAuth                          0.2.0
# Flask-Cors                               4.0.0
# flatbuffers                              23.5.26
# fonttools                                4.40.0
# fqdn                                     1.5.1
# frontmatter                              3.0.7
# frozenlist                               1.4.1
# fsspec                                   2024.2.0
# ftfy                                     6.1.3
# gast                                     0.5.4
# gcsfs                                    2024.2.0
# gensim                                   4.3.2
# gevent                                   23.9.1
# geventhttpclient                         2.0.11
# gitdb                                    4.0.11
# GitPython                                3.1.40
# glove-py                                 0.2.3
# google-ai-generativelanguage             0.6.4
# google-api-core                          2.13.0
# google-api-python-client                 2.134.0
# google-auth                              2.23.4
# google-auth-httplib2                     0.2.0
# google-auth-oauthlib                     1.2.0
# google-cloud-core                        2.3.3
# google-cloud-storage                     2.13.0
# google-crc32c                            1.5.0
# google-generativeai                      0.5.4
# google-pasta                             0.2.0
# google-resumable-media                   2.6.0
# googleapis-common-protos                 1.61.0
# gpt-pdf-md                               0.3
# gptcache                                 0.1.43
# greenlet                                 3.0.2
# grpcio                                   1.64.1
# grpcio-status                            1.62.2
# grpcio-tools                             1.64.1
# guidance                                 0.1.10
# gunicorn                                 21.2.0
# h11                                      0.14.0
# h2                                       4.1.0
# h5py                                     3.10.0
# hpack                                    4.0.0
# html2text                                2020.1.16
# httpcore                                 1.0.2
# httplib2                                 0.19.1
# httptools                                0.6.1
# httpx                                    0.27.0
# huggingface-hub                          0.23.4
# humanfriendly                            10.0
# hyperframe                               6.0.1
# idna                                     3.4
# importlib-metadata                       6.11.0
# importlib-resources                      6.1.1
# iniconfig                                2.0.0
# installer                                0.7.0
# ipinfo                                   5.0.0
# ipykernel                                6.27.1
# ipython                                  8.18.1
# ipywidgets                               8.1.1
# isodate                                  0.6.1
# isoduration                              20.11.0
# itsdangerous                             2.1.2
# jaraco.classes                           3.3.0
# jedi                                     0.19.1
# Jinja2                                   3.1.2
# jiter                                    0.5.0
# jmespath                                 1.0.1
# joblib                                   1.3.2
# json5                                    0.9.14
# jsonpatch                                1.33
# jsonpointer                              2.4
# jsonschema                               4.20.0
# jsonschema-specifications                2023.11.2
# jupyter                                  1.0.0
# jupyter_client                           8.6.0
# jupyter-console                          6.6.3
# jupyter_core                             5.5.0
# jupyter-events                           0.9.0
# jupyter-lsp                              2.2.1
# jupyter_server                           2.12.1
# jupyter_server_terminals                 0.5.0
# jupyterlab                               4.0.9
# jupyterlab_pygments                      0.3.0
# jupyterlab_server                        2.25.2
# jupyterlab-widgets                       3.0.9
# jupytext                                 1.16.0
# keras                                    3.0.5
# keyring                                  24.3.0
# kiwisolver                               1.4.4
# kubernetes                               30.1.0
# langchain                                0.2.6
# langchain-anthropic                      0.1.19
# langchain-community                      0.2.6
# langchain-core                           0.2.11
# langchain-experimental                   0.0.62
# langchain-google-genai                   1.0.6
# langchain-huggingface                    0.0.3
# langchain-openai                         0.1.14
# langchain-text-splitters                 0.2.2
# langchainhub                             0.1.20
# langcodes                                3.3.0
# langgraph                                0.1.5
# langsmith                                0.1.83
# libclang                                 16.0.6
# load-dotenv                              0.1.0
# locust                                   2.20.0
# lxml                                     5.1.0
# Mako                                     1.3.0
# mammoth                                  1.6.0
# Markdown                                 3.5.1
# markdown-it-py                           3.0.0
# markdownify                              0.11.6
# MarkupSafe                               2.1.3
# marshmallow                              3.20.1
# matplotlib                               3.9.1
# matplotlib-inline                        0.1.6
# mdit-py-plugins                          0.4.0
# mdurl                                    0.1.2
# mediapipe                                0.10.1
# mistune                                  3.0.2
# ml-dtypes                                0.3.2
# mlflow                                   2.6.0
# mlserver                                 1.3.5
# mlserver-mlflow                          1.3.5
# mlxtend                                  0.23.0
# mmh3                                     4.1.0
# monotonic                                1.6
# more-itertools                           10.2.0
# mpmath                                   1.3.0
# msal                                     1.26.0
# msgpack                                  1.0.7
# multidict                                6.0.4
# multiprocess                             0.70.15
# murmurhash                               1.0.10
# mypy-extensions                          1.0.0
# namex                                    0.0.7
# nbclient                                 0.9.0
# nbconvert                                7.12.0
# nbformat                                 5.9.2
# nest-asyncio                             1.5.8
# networkx                                 3.2.1
# nltk                                     3.8.1
# notebook                                 7.0.6
# notebook_shim                            0.2.3
# numpy                                    1.25.0
# oauthlib                                 3.2.2
# onnxruntime                              1.18.1
# openai                                   1.35.7
# opencv-contrib-python                    4.7.0.72
# opencv-python                            4.7.0.72
# openpyxl                                 3.1.2
# opentelemetry-api                        1.25.0
# opentelemetry-exporter-otlp-proto-common 1.25.0
# opentelemetry-exporter-otlp-proto-grpc   1.25.0
# opentelemetry-instrumentation            0.46b0
# opentelemetry-instrumentation-asgi       0.46b0
# opentelemetry-instrumentation-fastapi    0.46b0
# opentelemetry-proto                      1.25.0
# opentelemetry-sdk                        1.25.0
# opentelemetry-semantic-conventions       0.46b0
# opentelemetry-util-http                  0.46b0
# opt-einsum                               3.3.0
# ordered-set                              4.1.0
# orjson                                   3.10.5
# overrides                                7.4.0
# packaging                                23.2
# pandas                                   2.2.2
# pandocfilters                            1.5.0
# parso                                    0.8.3
# passlib                                  1.7.4
# pdf2image                                1.16.3
# pdfminer.six                             20221105
# pdfplumber                               0.10.3
# pexpect                                  4.9.0
# Pillow                                   9.5.0
# pinecone-client                          4.1.1
# pinecone-plugin-interface                0.0.7
# pip                                      24.0
# pip-autoremove                           0.10.0
# pipreqs                                  0.4.13
# pkginfo                                  1.9.6
# platformdirs                             3.11.0
# pluggy                                   1.3.0
# poetry                                   1.7.1
# poetry-core                              1.8.1
# poetry-plugin-export                     1.6.0
# portalocker                              2.10.0
# posthog                                  3.5.0
# pptx2md                                  1.5.0
# preshed                                  3.0.9
# prometheus-client                        0.19.0
# promise                                  2.3
# prompt-toolkit                           3.0.43
# proto-plus                               1.24.0
# protobuf                                 5.27.2
# psutil                                   5.9.6
# ptyprocess                               0.7.0
# pure-eval                                0.2.2
# py-grpc-prometheus                       0.7.0
# pyahocorasick                            2.0.0
# pyarrow                                  12.0.1
# pyarrow-hotfix                           0.6
# pyasn1                                   0.5.0
# pyasn1-modules                           0.3.0
# pybind11                                 2.11.1
# pycparser                                2.21
# pydantic                                 2.5.2
# pydantic_core                            2.14.5
# pydantic-settings                        2.1.0
# pydeck                                   0.8.1b0
# pydot                                    2.0.0
# pyformlang                               1.0.4
# Pygments                                 2.17.2
# PyJWT                                    2.7.0
# PyMuPDF                                  1.23.6
# PyMuPDFb                                 1.23.6
# PyMySQL                                  1.0.3
# pypandoc                                 1.12
# pyparsing                                2.4.7
# pypdf                                    4.2.0
# PyPDF2                                   3.0.1
# pypdfium2                                4.26.0
# PyPika                                   0.48.9
# pyproject_hooks                          1.0.0
# pyreqwest_impersonate                    0.4.8
# pytesseract                              0.3.10
# pytest                                   7.4.3
# python-dateutil                          2.8.2
# python-docx                              1.1.0
# python-dotenv                            1.0.0
# python-frontmatter                       1.0.1
# python-json-logger                       2.0.7
# python-multipart                         0.0.6
# python-pptx                              0.6.23
# python-rapidjson                         1.14
# pytz                                     2023.3.post1
# PyYAML                                   6.0.1
# pyzmq                                    25.1.2
# qdrant-client                            1.10.0
# qtconsole                                5.5.1
# QtPy                                     2.4.1
# querystring-parser                       1.2.4
# rapidfuzz                                3.6.1
# redis                                    5.0.4
# referencing                              0.32.0
# regex                                    2023.12.25
# requests                                 2.31.0
# requests-oauthlib                        1.4.0
# requests-toolbelt                        1.0.0
# responses                                0.18.0
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rich                                     13.7.0
# roundrobin                               0.0.4
# rpds-py                                  0.13.2
# rsa                                      4.9
# s3transfer                               0.9.0
# safetensors                              0.4.1
# scikeras                                 0.12.0
# scikit-learn                             1.2.2
# scikit-surprise                          1.1.3
# scipy                                    1.11.4
# seaborn                                  0.13.2
# Send2Trash                               1.8.2
# sentence-transformers                    3.0.1
# seqeval                                  1.2.2
# setuptools                               69.1.0
# shellingham                              1.5.4
# six                                      1.16.0
# smart-open                               6.4.0
# smmap                                    5.0.1
# sniffio                                  1.3.0
# sounddevice                              0.4.6
# soupsieve                                2.5
# spacy                                    3.7.2
# spacy-legacy                             3.0.12
# spacy-loggers                            1.0.5
# span-marker                              1.5.0
# SQLAlchemy                               2.0.25
# SQLAlchemy-Utils                         0.38.3
# sqlalchemy2-stubs                        0.0.2a37
# sqlmodel                                 0.0.8
# sqlparse                                 0.4.4
# srsly                                    2.4.8
# stack-data                               0.6.3
# starlette                                0.27.0
# starlette-exporter                       0.17.1
# streamlit                                1.30.0
# streamlit-chat                           0.1.1
# striprtf                                 0.0.26
# surprise                                 0.1
# sympy                                    1.12
# tabulate                                 0.9.0
# tavily-python                            0.3.3
# tenacity                                 8.2.3
# tensorboard                              2.16.2
# tensorboard-data-server                  0.7.2
# tensorflow                               2.16.1
# tensorflow-datasets                      4.9.4
# tensorflow-io-gcs-filesystem             0.36.0
# tensorflow-macos                         2.16.1
# tensorflow-metadata                      1.14.0
# tensorflow-metal                         1.1.0
# termcolor                                2.4.0
# terminado                                0.18.0
# textblob                                 0.18.0.post0
# textsearch                               0.0.24
# thinc                                    8.2.2
# threadpoolctl                            3.2.0
# tiktoken                                 0.7.0
# tinycss2                                 1.2.1
# tokenizers                               0.19.1
# toml                                     0.10.2
# tomlkit                                  0.12.3
# toolz                                    0.12.0
# torch                                    2.1.2
# tornado                                  6.4
# tqdm                                     4.66.1
# traitlets                                5.14.0
# transformers                             4.41.2
# tritonclient                             2.40.0
# trove-classifiers                        2024.1.8
# typer                                    0.9.0
# types-python-dateutil                    2.8.19.14
# types-requests                           2.32.0.20240622
# typing_extensions                        4.9.0
# typing-inspect                           0.9.0
# tzdata                                   2023.3
# tzlocal                                  5.2
# Unidecode                                1.3.8
# uri-template                             1.3.0
# uritemplate                              4.1.1
# urllib3                                  2.1.0
# uvicorn                                  0.24.0.post1
# uvloop                                   0.19.0
# vaderSentiment                           3.3.2
# validators                               0.18.2
# virtualenv                               20.25.0
# wasabi                                   1.1.2
# watchfiles                               0.21.0
# wcwidth                                  0.2.12
# weasel                                   0.3.4
# webcolors                                1.13
# webencodings                             0.5.1
# websocket-client                         1.7.0
# websockets                               12.0
# Werkzeug                                 3.0.1
# wheel                                    0.42.0
# widgetsnbextension                       4.0.9
# wikipedia                                1.4.0
# wrapt                                    1.16.0
# xattr                                    0.10.1
# XlsxWriter                               3.1.9
# xxhash                                   3.4.1
# yarg                                     0.1.9
# yarl                                     1.9.4
# zenml                                    0.52.0
# zipp                                     3.17.0
# zope.event                               5.0
# zope.interface                           6.1
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
try:
    import llama_index
    print("llama_index is still installed.")
except ImportError:
    print("llama_index has been successfully uninstalled.")
# Out:
# llama_index is still installed.

# %%
# !pip list | grep llama_index
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
