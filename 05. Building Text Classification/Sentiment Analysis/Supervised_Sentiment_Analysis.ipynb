# %%
import pandas as pd
import numpy as np
import nltk

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
reviews = pd.read_csv('movie_reviews.csv')

# %%
reviews.sentiment.value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
reviews.sample(3000).sentiment.value_counts()
# Out:
# sentiment
# negative    1507
# positive    1493
# Name: count, dtype: int64

# %%
reviews_sample = reviews.sample(3000)

# %%
reviews_sample.sentiment.value_counts()
# Out:
# sentiment
# positive    1573
# negative    1427
# Name: count, dtype: int64

# %%
reviews_sample = reviews_sample.reset_index().drop(columns = 'index')

# %%
reviews_sample
# Out:
#                                                  review sentiment
# 0     I saw this recently and I must say, I was move...  negative
# 1     Have to disagree with people saying that this ...  negative
# 2     This is an amazing movie and all of the actors...  positive
# 3     I expected this movie was originally supposed ...  negative
# 4     In the first transformation scene, what is the...  positive
# ...                                                 ...       ...
# 2995  Rififi is a great film that is overlooked. It'...  positive
# 2996  Like many, this dung heap caught my eye while ...  negative
# 2997  A not bad but also not so great heist film. Ki...  negative
# 2998  Classic, highly influential low budget thrille...  positive
# 2999  That was the first thing that sprang to mind a...  positive
#
# [3000 rows x 2 columns]

# %%
import nltk
import re
from bs4 import BeautifulSoup

stop_words = nltk.corpus.stopwords.words('english')


def strip_html(doc):
    soup = BeautifulSoup(doc,"html.parser")
    text = soup.get_text()
    return text
    

def normalize_document(doc):
    doc = strip_html(doc)
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I|re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = nltk.word_tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc

# %%
reviews_sample['review_sample'] = reviews_sample['review'].apply(normalize_document)
# Out:
# /var/folders/j8/wb7_9rh96f9g2r0vvmqchbd80000gn/T/ipykernel_89704/3622159626.py:9: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(doc,"html.parser")

# %%
reviews_sample
# Out:
#                                                  review sentiment  \
# 0     I saw this recently and I must say, I was move...  negative
# 1     Have to disagree with people saying that this ...  negative
# 2     This is an amazing movie and all of the actors...  positive
# 3     I expected this movie was originally supposed ...  negative
# 4     In the first transformation scene, what is the...  positive
# ...                                                 ...       ...
# 2995  Rififi is a great film that is overlooked. It'...  positive
# 2996  Like many, this dung heap caught my eye while ...  negative
# 2997  A not bad but also not so great heist film. Ki...  negative
# 2998  Classic, highly influential low budget thrille...  positive
# 2999  That was the first thing that sprang to mind a...  positive
#
#                                           review_sample
# 0     saw recently must say moved factual basis stor...
# 1     disagree people saying lousy horror film good ...
# 2     amazing movie actors actresses good even thoug...
# 3     expected movie originally supposed show electi...
# 4     first transformation scene music ive heard gre...
# ...                                                 ...
# 2995  rififi great film overlooked crime drama man g...
# 2996  like many dung heap caught eye channel surfing...
# 2997  bad also great heist film kirk douglas recentl...
# 2998  classic highly influential low budget thriller...
# 2999  first thing sprang mind watched closing credit...
#
# [3000 rows x 3 columns]

# %%
X = reviews_sample['review_sample']
y = reviews_sample['sentiment']

# %%
train_X, test_X, train_y, test_y = train_test_split(X,y, test_size=0.33, random_state=23)

# %%
train_X.shape, test_X.shape, train_y.shape, test_y.shape
# Out:
# ((2010,), (990,), (2010,), (990,))

# %% [markdown]
# # Count Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(binary=True)

# %%
cv_transfored_train_X = cv.fit_transform(train_X)
cv_transfored_test_X = cv.transform(test_X)

# %%
model = LogisticRegression()

# %%
model.fit(cv_transfored_train_X, train_y)
# Out:
# LogisticRegression()

# %%
train_pred = model.predict(cv_transfored_train_X)
test_pred = model.predict(cv_transfored_test_X)

# %%
confusion_matrix(train_y, train_pred)
# Out:
# array([[ 957,    0],
#        [   0, 1053]])

# %%
confusion_matrix(test_y, test_pred)
# Out:
# array([[363, 107],
#        [ 55, 465]])

# %%
print("Train Accuracy : ",accuracy_score(train_y, train_pred))
print("Test Accuracy : ",accuracy_score(test_y, test_pred))
# Out:
# Train Accuracy :  1.0
# Test Accuracy :  0.8363636363636363

# %% [markdown]
# # Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(binary=False)

# %%
cv_transfored_train_X = cv.fit_transform(train_X)
cv_transfored_test_X = cv.transform(test_X)

# %%
model = LogisticRegression()

# %%
model.fit(cv_transfored_train_X, train_y)
# Out:
# LogisticRegression()

# %%
train_pred = model.predict(cv_transfored_train_X)
test_pred = model.predict(cv_transfored_test_X)

# %%
confusion_matrix(train_y, train_pred)
# Out:
# array([[1032,    0],
#        [   0,  978]])

# %%
confusion_matrix(test_y, test_pred)
# Out:
# array([[399,  95],
#        [ 99, 397]])

# %%
print("Train Accuracy : ",accuracy_score(train_y, train_pred))
print("Test Accuracy : ",accuracy_score(test_y, test_pred))
# Out:
# Train Accuracy :  1.0
# Test Accuracy :  0.804040404040404

# %% [markdown]
# # TF - IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tf = TfidfVectorizer()

# %%
tf_transfored_train_X = tf.fit_transform(train_X)
tf_transfored_test_X = tf.transform(test_X)

# %%
model = LogisticRegression()

# %%
model.fit(tf_transfored_train_X, train_y)
# Out:
# LogisticRegression()

# %%
train_pred = model.predict(tf_transfored_train_X)
test_pred = model.predict(tf_transfored_test_X)

# %%
confusion_matrix(train_y, train_pred)
# Out:
# array([[1014,   18],
#        [  26,  952]])

# %%
confusion_matrix(test_y, test_pred)
# Out:
# array([[404,  90],
#        [100, 396]])

# %%
print("Train Accuracy : ",accuracy_score(train_y, train_pred))
print("Test Accuracy : ",accuracy_score(test_y, test_pred))
# Out:
# Train Accuracy :  0.9781094527363184
# Test Accuracy :  0.8080808080808081

# %% [markdown]
# # Word Embeddings

# %% [markdown]
# ### Glove

# %%
# Load GloVe embeddings into a dictionary
def load_embeddings(file_path):
    embeddings = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], dtype='float32')
            embeddings[word] = vector
    return embeddings

glove_embeddings_path = 'glove.6B.300d.txt'  # Adjust the path to your downloaded GloVe file
wv = load_embeddings(glove_embeddings_path)

# %%
def average_word_vectors(words, model, vocabulary, num_features):
    
    feature_vector = np.zeros((num_features,),dtype="float64")
    nwords = 0.
    
    for word in words:
        if word in vocabulary: 
            nwords = nwords + 1.
            feature_vector = np.add(feature_vector, model[word])
    
    if nwords:
        feature_vector = np.divide(feature_vector, nwords)
        
    return feature_vector


def averaged_word_vectorizer(corpus, model, num_features):
    vocabulary = set(model.keys())
    features = [average_word_vectors(tokenized_sentence, model, vocabulary, num_features)
                    for tokenized_sentence in corpus]
    return np.array(features)

# %%
normalize_corpus = np.vectorize(normalize_document)
train_norm_corpus = normalize_corpus(train_X)
train_tokenized_corpus = [nltk.word_tokenize(doc) for doc in train_norm_corpus]

test_norm_corpus = normalize_corpus(test_X)
test_tokenized_corpus = [nltk.word_tokenize(doc) for doc in test_norm_corpus]

# %%
# get document level embeddings
feature_size = 300
train_features_X = averaged_word_vectorizer(corpus=train_tokenized_corpus, model=wv,
                                             num_features=feature_size)

test_features_X = averaged_word_vectorizer(corpus=test_tokenized_corpus, model=wv,
                                             num_features=feature_size)

# %%
pd.DataFrame(train_features_X)
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.049165  0.052444  0.031960 -0.071950  0.032793  0.048069 -0.053564
# 1    -0.105681  0.045909 -0.004646 -0.030854  0.056146  0.005300 -0.034945
# 2    -0.046176 -0.007872 -0.054750 -0.051546  0.019541 -0.028307 -0.063718
# 3    -0.084055  0.144388 -0.048921 -0.061271  0.001274  0.099269 -0.019970
# 4    -0.055458  0.043987 -0.013972 -0.056797 -0.022531  0.055491 -0.064837
# ...        ...       ...       ...       ...       ...       ...       ...
# 2005 -0.100532 -0.029887  0.067890 -0.044762  0.107496  0.106629 -0.144847
# 2006 -0.091245  0.056812 -0.036939 -0.012791  0.003856  0.051798 -0.093165
# 2007 -0.085236  0.001140 -0.006074 -0.082129  0.025673  0.047489 -0.065533
# 2008 -0.043361  0.118525 -0.025280 -0.054349  0.082131  0.001435 -0.151787
# 2009 -0.053278  0.063018 -0.051530 -0.058551 -0.049926  0.041062 -0.007632
#
#            7         8         9    ...       290       291       292  \
# 0     0.016657  0.024148 -1.108993  ... -0.045978 -0.073211 -0.046919
# 1    -0.006234  0.074045 -0.909599  ...  0.002156 -0.043157 -0.000104
# 2    -0.053443 -0.029368 -0.912395  ...  0.036766 -0.028397  0.028678
# 3     0.023440 -0.033673 -0.991250  ... -0.048714 -0.037017 -0.060602
# 4     0.089841  0.040812 -0.844451  ...  0.020417 -0.099706 -0.055017
# ...        ...       ...       ...  ...       ...       ...       ...
# 2005  0.031142  0.083907 -1.031707  ...  0.041463  0.017034 -0.073145
# 2006 -0.099857 -0.033069 -0.845264  ...  0.002284 -0.117497 -0.077910
# 2007 -0.062481  0.024915 -1.008796  ... -0.017099 -0.110478  0.072349
# 2008 -0.011836 -0.015750 -0.884487  ...  0.030698 -0.063872 -0.075988
# 2009 -0.042195  0.032671 -1.089669  ... -0.071655 -0.029945 -0.008109
#
#            293       294       295       296       297       298       299
# 0     0.012517  0.001496  0.004134 -0.050841  0.019352 -0.050495 -0.000791
# 1     0.010153  0.041413 -0.059955 -0.016339 -0.022908 -0.091051  0.020144
# 2     0.149325 -0.007303 -0.064194 -0.033430 -0.045291 -0.100903  0.101187
# 3     0.010045  0.022147 -0.122591  0.001777 -0.073922 -0.026341 -0.010161
# 4     0.071576 -0.011612 -0.147060  0.054429 -0.018500 -0.078385  0.151170
# ...        ...       ...       ...       ...       ...       ...       ...
# 2005  0.070133 -0.088130 -0.013833 -0.103302 -0.045891 -0.061425  0.054517
# 2006  0.057344  0.021356 -0.041718  0.002215 -0.032273 -0.013484  0.031794
# 2007  0.034391  0.028183 -0.107158  0.054900 -0.003695 -0.079584  0.042854
# 2008 -0.017931 -0.083995  0.036870 -0.005913 -0.076154 -0.063887  0.105094
# 2009  0.032824  0.052330 -0.197308  0.000023  0.050449 -0.054900  0.064423
#
# [2010 rows x 300 columns]

# %%
pd.DataFrame(test_features_X)
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.052537  0.091124 -0.065973 -0.021576  0.022972  0.134362 -0.070737
# 1   -0.072845  0.047125  0.021333 -0.093270  0.088039  0.081752 -0.102703
# 2   -0.029183 -0.019746 -0.011152 -0.040143  0.004725 -0.008937 -0.090370
# 3   -0.069958  0.084086 -0.055243 -0.122744 -0.030658  0.106131 -0.042479
# 4   -0.079415  0.054271 -0.027632  0.016405  0.026526  0.055384 -0.057809
# ..        ...       ...       ...       ...       ...       ...       ...
# 985 -0.022409 -0.023695 -0.024228 -0.038190  0.028569  0.019978 -0.017572
# 986 -0.119466  0.004307 -0.053651 -0.074866 -0.046343  0.044201 -0.098234
# 987 -0.011719  0.055906  0.007184 -0.069013  0.010372  0.095319 -0.135913
# 988 -0.060785  0.023363 -0.039515 -0.061046  0.042034  0.045911 -0.117750
# 989 -0.134925 -0.005083 -0.026794 -0.115491  0.011021  0.071380 -0.034226
#
#           7         8         9    ...       290       291       292  \
# 0    0.091711  0.045290 -1.134408  ...  0.019397 -0.237070 -0.108205
# 1    0.015140  0.065554 -1.089631  ...  0.013210 -0.163945 -0.123100
# 2    0.030888  0.054048 -0.974858  ... -0.030922 -0.078219  0.000690
# 3    0.070517  0.061982 -0.914609  ...  0.035870 -0.032976 -0.075464
# 4    0.006547  0.039659 -0.755967  ... -0.054058 -0.086566 -0.048011
# ..        ...       ...       ...  ...       ...       ...       ...
# 985  0.096081  0.035262 -1.069151  ...  0.046890 -0.076336  0.008560
# 986  0.004778  0.014118 -1.069709  ...  0.058214 -0.097406 -0.091344
# 987 -0.019853 -0.005765 -1.078017  ... -0.023421 -0.109827 -0.051343
# 988 -0.054647  0.080711 -0.929332  ... -0.013616 -0.018049 -0.047607
# 989 -0.082380 -0.028343 -1.057106  ...  0.008249 -0.030082  0.005023
#
#           293       294       295       296       297       298       299
# 0   -0.078260 -0.190459 -0.159598  0.047273  0.077141  0.004034 -0.028294
# 1    0.015224 -0.052538  0.138016 -0.032549 -0.034749  0.010404  0.057869
# 2    0.067660  0.044929 -0.163237 -0.106094  0.078722 -0.050162  0.009220
# 3    0.004362 -0.037075 -0.009298  0.029799  0.023376  0.004521  0.049957
# 4   -0.012868  0.047532 -0.168991  0.020066  0.018346 -0.051851  0.111961
# ..        ...       ...       ...       ...       ...       ...       ...
# 985  0.098530 -0.066955 -0.130243  0.028522 -0.094712 -0.023147  0.048259
# 986 -0.036342 -0.073859 -0.153723 -0.028258  0.034064  0.035100  0.092933
# 987  0.017536  0.048360 -0.025041  0.029640 -0.046908 -0.091542  0.060366
# 988  0.060981 -0.000740 -0.024292  0.023542 -0.009262 -0.021186  0.060067
# 989 -0.033027 -0.028060 -0.058163 -0.021358  0.011403  0.006435 -0.116523
#
# [990 rows x 300 columns]

# %%
model = LogisticRegression()

# %%
model.fit(train_features_X, train_y)
# Out:
# LogisticRegression()

# %%
train_pred = model.predict(train_features_X)
test_pred = model.predict(test_features_X)

# %%
confusion_matrix(train_y, train_pred)
# Out:
# array([[878, 154],
#        [179, 799]])

# %%
confusion_matrix(test_y, test_pred)
# Out:
# array([[408,  86],
#        [111, 385]])

# %%
print("Train Accuracy : ",accuracy_score(train_y, train_pred))
print("Test Accuracy : ",accuracy_score(test_y, test_pred))
# Out:
# Train Accuracy :  0.8343283582089552
# Test Accuracy :  0.8010101010101011

# %% [markdown]
# # Glove with Deep Learning Architecture

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout, BatchNormalization
from keras.utils import to_categorical

# %%
y_cat_train = to_categorical(np.asarray(train_y.factorize()[0]))
y_cat_test = to_categorical(np.asarray(test_y.factorize()[0]))

# %%
model = Sequential()
model.add(Dense(64, kernel_initializer = 'he_normal', input_shape = (300,),activation = 'elu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(32, kernel_initializer = 'he_normal', activation = 'elu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(16 ,kernel_initializer = 'he_normal',activation = 'elu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(8 ,kernel_initializer = 'he_normal', activation = 'elu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(4 ,kernel_initializer = 'he_normal', activation = 'elu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(2, kernel_initializer = 'he_normal', activation = 'softmax'))
# Out:
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/core/dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │        19,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 8)              │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 4)              │            16 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 2)              │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,550 (88.09 KB)
#  Trainable params: 22,302 (87.12 KB)
#  Non-trainable params: 248 (992.00 B)

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'] )

# %%
history = model.fit(train_features_X,y_cat_train,epochs = 100, verbose = 1, batch_size=100)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5063 - loss: 0.9787
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6025 - loss: 0.8067
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6311 - loss: 0.7481
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6673 - loss: 0.6984
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6952 - loss: 0.6568
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.7005 - loss: 0.6240
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.7352 - loss: 0.6065
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.7595 - loss: 0.5742
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.7422 - loss: 0.5787
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 0.7777 - loss: 0.5449
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.7852 - loss: 0.5205
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.7828 - loss: 0.5077
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.7829 - loss: 0.5114
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.8082 - loss: 0.4654
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.8063 - loss: 0.4677
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8024 - loss: 0.4628
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.8364 - loss: 0.4381
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.8199 - loss: 0.4385
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.8281 - loss: 0.4368
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.8361 - loss: 0.4174
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.8232 - loss: 0.4462
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.8562 - loss: 0.4112
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.8605 - loss: 0.3854
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.8591 - loss: 0.3893
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.8505 - loss: 0.4061
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - accuracy: 0.8539 - loss: 0.4083
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.8457 - loss: 0.3873
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.8518 - loss: 0.3920
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8626 - loss: 0.3820
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.8613 - loss: 0.3697
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.8622 - loss: 0.3686
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.8556 - loss: 0.3718
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 0.8596 - loss: 0.3692
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.8685 - loss: 0.3695
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.8615 - loss: 0.3549
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.8655 - loss: 0.3539
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.8698 - loss: 0.3474
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.8714 - loss: 0.3456
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 0.8628 - loss: 0.3563
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.8709 - loss: 0.3516
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.8596 - loss: 0.3531
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.8680 - loss: 0.3400
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.8909 - loss: 0.3179
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.8865 - loss: 0.3321
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.8864 - loss: 0.3174
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.8864 - loss: 0.3323
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.8828 - loss: 0.3211
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 0.8885 - loss: 0.3186
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.8756 - loss: 0.3379
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 0.8859 - loss: 0.3191
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8854 - loss: 0.3079
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - accuracy: 0.9008 - loss: 0.2964
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.8942 - loss: 0.2945
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.8948 - loss: 0.3177
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 0.8968 - loss: 0.2948
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.8814 - loss: 0.3095
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 0.8974 - loss: 0.2951
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.9060 - loss: 0.2841
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.9114 - loss: 0.2895
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.9070 - loss: 0.2701
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.9060 - loss: 0.2867
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - accuracy: 0.8956 - loss: 0.2983
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.8963 - loss: 0.2851
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 0.9001 - loss: 0.2873
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.9046 - loss: 0.2557
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 0.9075 - loss: 0.2755
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.9174 - loss: 0.2468
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - accuracy: 0.9084 - loss: 0.2462
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.9009 - loss: 0.2774
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9171 - loss: 0.2342
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.9241 - loss: 0.2282
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - accuracy: 0.8988 - loss: 0.2702
# Epoch 73/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.8994 - loss: 0.2872
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.9095 - loss: 0.2803
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 0.9177 - loss: 0.2396
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.9163 - loss: 0.2382
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.9128 - loss: 0.2672
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.9236 - loss: 0.2360
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.9306 - loss: 0.2199
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.9039 - loss: 0.2577
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.9209 - loss: 0.2522
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 0.9324 - loss: 0.2137
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.9200 - loss: 0.2319
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.9434 - loss: 0.2034
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.9279 - loss: 0.2088
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.9338 - loss: 0.2074
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.9283 - loss: 0.2171
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.9338 - loss: 0.2026
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.9465 - loss: 0.1855
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 0.9446 - loss: 0.1958
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - accuracy: 0.9387 - loss: 0.2000
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9359 - loss: 0.1950
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.9296 - loss: 0.2054
# Epoch 94/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.9362 - loss: 0.2012
# Epoch 95/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.9379 - loss: 0.1925
# Epoch 96/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.9311 - loss: 0.2137
# Epoch 97/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.9263 - loss: 0.2271
# Epoch 98/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.9409 - loss: 0.1874
# Epoch 99/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - accuracy: 0.9392 - loss: 0.1905
# Epoch 100/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.9422 - loss: 0.1958

# %%
train_pred = np.argmax(model.predict(train_features_X), axis = 1)
test_pred = np.argmax(model.predict(test_features_X), axis = 1)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step

# %%
train_pred = np.where(train_pred ==0, 'positive', 'negative')
test_pred = np.where(test_pred ==0, 'positive', 'negative')

# %%
print("Train Accuracy : ",accuracy_score(train_y, train_pred))
print("Test Accuracy : ",accuracy_score(test_y, test_pred))
# Out:
# Train Accuracy :  0.9786069651741294
# Test Accuracy :  0.7666666666666667

# %%
# https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit?resourcekey=0-wjGZdNAUop6WykTtMip30g

# %%
#FastText Embedding Vector Download
#https://fasttext.cc/docs/en/english-vectors.html

# %% [markdown]
# # Word2vec Pretraining model

# %%
from gensim.models import Word2Vec, KeyedVectors
from nltk.tokenize import word_tokenize

# %%
path_to_model = 'word2vec-google-news-300.bin'

#Load W2V model. This will take some time. 
# %time w2v_model = KeyedVectors.load_word2vec_format(path_to_model, binary=True)
print('done loading Word2Vec')
# Out:
# CPU times: user 6.51 s, sys: 742 ms, total: 7.25 s
# Wall time: 7.77 s
# done loading Word2Vec

# %%
#Inspect the model
print('Shape :',w2v_model.vectors.shape)
word2vec_vocab = w2v_model.index_to_key 
word2vec_vocab_lower = [item.lower() for item in word2vec_vocab]
print('Total vocabulary counts :',len(word2vec_vocab))
# Out:
# Shape : (3000000, 300)
# Total vocabulary counts : 3000000

# %%
for word in train_tokenized_corpus[0]:
    try:
        word = word.lower()
        embeddings = w2v_model.key_to_index[word]
        print(word,'-->',embeddings)
    except:
        print(word)
# Out:
# story --> 550
# documenting --> 20656
# rise --> 1027
# chinas
# first --> 56
# emperor --> 30068
# efforts --> 763
# unify --> 25688
# empire --> 10746
# expensive --> 2414
# movie --> 1121
# production --> 620
# chinese --> 100038
# historyits
# worth --> 1069
# every --> 274
# penny --> 8725
# visually --> 20622
# dazzling --> 16782
# cinematography --> 37101
# sweeping --> 6378
# score --> 1012
# outstanding --> 1890
# characters --> 3304
# make --> 109
# one --> 45
# finest --> 8214
# epics --> 71594
# ever --> 518
# put --> 238
# film --> 692
# foreign --> 754
# otherwise --> 2357
# please --> 2456
# miss --> 2116
# opportunity --> 703
# see --> 158
# big --> 276
# screen --> 1973

# %%
# Creating a feature vector by averaging all embeddings for all sentences
def features_embeddings(list_of_lists):
    
    # feature vector column length 
    DIMENSION = w2v_model.vector_size
    
    # Zero vector if words not in our w2v_model vocubulary
    zero_vector = np.zeros(DIMENSION)
    
    features = []
    
    # feature vector for each sentence in list_of_lists one by one
    for tokens in list_of_lists:
        
        # feature vector for a single sentence
        feature =  np.zeros(DIMENSION) # shape = 1X DIMENSION
        
        # count for each token/word in a tokens or sentence
        feature_counts = 0 + 1e-5   # to avoid divide-by-zero 
        for token in tokens:
            if token in w2v_model:
                feature += w2v_model[token] # Here both feature and w2v_model[token] are of same shape : 1X DIMENSION
                feature_counts +=1    # Count increases for each token in a tokens
         
        # Average the feature values for each tokens
        if(feature_counts !=0 ):        # for non empty tokens
            features.append(feature/feature_counts) 
        else:                           # for empty tokens
            features.append(zero_vector)
            
    return features

# %%
train_vectors = features_embeddings(train_tokenized_corpus)
print(len(train_vectors))
train_vectors[0].shape
# Out:
# 2010
# (300,)

# %%
test_vectors = features_embeddings(test_tokenized_corpus)
print(len(test_vectors))
test_vectors[0].shape
# Out:
# 990
# (300,)

# %%
pd.DataFrame(train_vectors)
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.025413  0.017893  0.009669  0.100787  0.006266  0.008118  0.087102
# 1     0.041864  0.029539 -0.003314  0.060085 -0.037326  0.024126  0.069229
# 2     0.058087  0.059167 -0.002032  0.059178 -0.067313 -0.008359  0.055403
# 3     0.055705  0.011109 -0.012106  0.110000 -0.038259 -0.005965  0.032449
# 4     0.055795  0.065975  0.007370  0.097802 -0.042695 -0.013492  0.041037
# ...        ...       ...       ...       ...       ...       ...       ...
# 2005  0.077894  0.048710 -0.000583  0.103553 -0.087790  0.059894  0.082951
# 2006  0.044526  0.053642  0.012405  0.116098 -0.079652  0.042850  0.064464
# 2007  0.051548  0.046371  0.011113  0.081187 -0.054934  0.000628  0.046997
# 2008  0.046670  0.050964 -0.023507  0.095043 -0.012921 -0.019055  0.035108
# 2009  0.031206  0.053334  0.012577  0.081815 -0.034789 -0.017460  0.038583
#
#            7         8         9    ...       290       291       292  \
# 0    -0.022144  0.094054  0.093803  ... -0.134564  0.016229 -0.099295
# 1    -0.044021  0.081423  0.041232  ... -0.137162  0.055503 -0.123243
# 2    -0.065988  0.090547  0.091691  ... -0.106429  0.020701 -0.087849
# 3    -0.006873  0.073128  0.077147  ... -0.070112  0.076626 -0.136963
# 4    -0.053537  0.053832  0.062231  ... -0.048031  0.038145 -0.087831
# ...        ...       ...       ...  ...       ...       ...       ...
# 2005 -0.036448  0.093953  0.095390  ... -0.098446  0.056713 -0.084245
# 2006 -0.086374  0.069077  0.077816  ... -0.031583  0.085157 -0.107991
# 2007 -0.069626  0.075349  0.078323  ... -0.056852  0.055989 -0.086515
# 2008 -0.045781  0.077376  0.050663  ... -0.039909  0.045488 -0.077940
# 2009 -0.073359  0.049860  0.069712  ... -0.027770  0.056752 -0.099040
#
#            293       294       295       296       297       298       299
# 0     0.033675 -0.013184 -0.042983 -0.013791 -0.068369  0.027123 -0.027254
# 1    -0.004244 -0.045488 -0.014705  0.026503 -0.036409  0.060550 -0.020487
# 2     0.028960 -0.039412 -0.018355  0.006856 -0.051078  0.029464 -0.021360
# 3     0.027219 -0.047677 -0.033622  0.011968 -0.064334 -0.002256  0.021236
# 4     0.019510 -0.049447 -0.020297  0.035594 -0.054443  0.001766 -0.020204
# ...        ...       ...       ...       ...       ...       ...       ...
# 2005 -0.011151 -0.068074 -0.021399  0.044470 -0.062348  0.042190  0.017638
# 2006  0.040527 -0.072522 -0.061935  0.003120 -0.048855 -0.002187 -0.013914
# 2007  0.009794 -0.051231  0.006207  0.023844 -0.069063  0.019625  0.010695
# 2008 -0.015282 -0.033841 -0.007587  0.033654 -0.057930  0.020167  0.016718
# 2009  0.010804 -0.059935  0.014052  0.032139 -0.026255  0.042523  0.019454
#
# [2010 rows x 300 columns]

# %%
model = LogisticRegression()

# %%
model.fit(train_vectors, train_y)
# Out:
# LogisticRegression()

# %%
train_pred = model.predict(train_vectors)
test_pred = model.predict(test_vectors)

# %%
confusion_matrix(train_y, train_pred)
# Out:
# array([[885, 147],
#        [175, 803]])

# %%
confusion_matrix(test_y, test_pred)
# Out:
# array([[427,  67],
#        [118, 378]])

# %%
print("Train Accuracy : ",accuracy_score(train_y, train_pred))
print("Test Accuracy : ",accuracy_score(test_y, test_pred))
# Out:
# Train Accuracy :  0.8398009950248756
# Test Accuracy :  0.8131313131313131

# %% [markdown]
# # Word2vec Training

# %%
# Creating a feature vector by averaging all embeddings for all sentences
def features_embeddings_trained(list_of_lists):
    
    # feature vector column length 
    DIMENSION = w2v_model.vector_size
    
    # Zero vector if words not in our w2v_model vocubulary
    zero_vector = np.zeros(DIMENSION)
    
    features = []
    
    # feature vector for each sentence in list_of_lists one by one
    for tokens in list_of_lists:
        
        # feature vector for a single sentence
        feature =  np.zeros(DIMENSION) # shape = 1X DIMENSION
        
        # count for each token/word in a tokens or sentence
        feature_counts = 0 + 1e-5   # to avoid divide-by-zero 
        for token in tokens:
            if token in w2v_model.wv.index_to_key:
                feature += w2v_model.wv[token] # Here both feature and w2v_model[token] are of same shape : 1X DIMENSION
                feature_counts +=1    # Count increases for each token in a tokens
         
        # Average the feature values for each tokens
        if(feature_counts !=0 ):        # for non empty tokens
            features.append(feature/feature_counts) 
        else:                           # for empty tokens
            features.append(zero_vector)
            
    return features

# %%
tokenized_corpus = train_tokenized_corpus + test_tokenized_corpus

# %%
train_tokenized_corpus
# Out:
# [['intense',
#   'fascinating',
#   'drama',
#   'similarities',
#   'tone',
#   'subject',
#   'films',
#   'like',
#   'bully',
#   'elephant',
#   'kids',
#   'although',
#   'point',
#   'view',
#   'superior',
#   'film',
#   'three',
#   'onesbefore',
#   'watching',
#   'movie',
#   'expectations',
#   'neutral',
#   'ended',
#   'taking',
#   'good',
#   'impression',
#   'thanks',
#   'intelligent',
#   'screenplay',
#   'murali',
#   'k',
#   'thalluris',
#   'perfect',
#   'direction',
#   'excellent',
#   'performances',
#   'group',
#   'young',
#   'actorsthe',
#   'sporadic',
#   'instances',
#   'school',
#   'violence',
#   'around',
#   'world',
#   'inspired',
#   'many',
#   'movies',
#   'tv',
#   'programmes',
#   'books',
#   'pretend',
#   'find',
#   'predict',
#   'external',
#   'internal',
#   'reasons',
#   'unbridled',
#   'expressions',
#   'rebelliousness',
#   'discontentand',
#   'specially',
#   'madnesssome',
#   'people',
#   'may',
#   'say',
#   'arrives',
#   'late',
#   'artistic',
#   'movement',
#   'however',
#   'think',
#   'like',
#   'delay',
#   'permitted',
#   'movie',
#   'make',
#   'artistic',
#   'analysis',
#   'focusing',
#   'situation',
#   'subtleness',
#   'intelligence',
#   'instead',
#   'obvious',
#   'reaction',
#   'cruelty',
#   'anguish',
#   'impregnated',
#   'movies',
#   'similar',
#   'storieson',
#   'characters',
#   'find',
#   'clichs',
#   'juvenile',
#   'cinema',
#   'director',
#   'screenwriter',
#   'john',
#   'hughes',
#   'rips',
#   'movies',
#   'teen',
#   'horror',
#   'films',
#   'beautiful',
#   'princess',
#   'clumsy',
#   'nerd',
#   'antipathetic',
#   'athletes',
#   'etcit',
#   'would',
#   'easy',
#   'make',
#   'become',
#   'hollow',
#   'caricatures',
#   'defined',
#   'function',
#   'screenplay',
#   'something',
#   'admirable',
#   'screenplay',
#   'transcends',
#   'stereotypes',
#   'make',
#   'real',
#   'people',
#   'credible',
#   'problems',
#   'less',
#   'degree',
#   'person',
#   'find',
#   'hisher',
#   'road',
#   'maturity',
#   'excellent',
#   'movie',
#   'whose',
#   'fail',
#   'ending',
#   'feels',
#   'bit',
#   'affected',
#   'compensates',
#   'lot',
#   'positive',
#   'elementsit',
#   'interesting',
#   'see',
#   'thalluris',
#   'next',
#   'projects',
#   'since',
#   'great',
#   'debut',
#   'movie'],
#  ['ah',
#   'yet',
#   'another',
#   'seagal',
#   'moviein',
#   'less',
#   'mere',
#   'months',
#   'arrive',
#   'populate',
#   'video',
#   'store',
#   'shelvesas',
#   'bad',
#   'submergednobut',
#   'saying',
#   'muchlike',
#   'perfume',
#   'pigseagal',
#   'professional',
#   'thief',
#   'wants',
#   'quitbut',
#   'goes',
#   'one',
#   'last',
#   'job',
#   'doublecrossed',
#   'bosshe',
#   'lands',
#   'prison',
#   'befriended',
#   'gangster',
#   'helps',
#   'break',
#   'seek',
#   'paybackits',
#   'good',
#   'see',
#   'seagal',
#   'finally',
#   'playing',
#   'agentcopor',
#   'usually',
#   'playswe',
#   'actually',
#   'get',
#   'usa',
#   'location',
#   'las',
#   'vegas',
#   'seems',
#   'eastern',
#   'european',
#   'territory',
#   'usual',
#   'wirefu',
#   'either',
#   'heredon',
#   'fauntleroy',
#   'okay',
#   'jobhowever',
#   'action',
#   'fight',
#   'scenes',
#   'stevie',
#   'clearly',
#   'doublesscenes',
#   'moviesa',
#   'lack',
#   'realism',
#   'logic',
#   'even',
#   'tiniest',
#   'situationseagal',
#   'treech',
#   'make',
#   'soso',
#   'team',
#   'inspiringunintentional',
#   'laughs',
#   'one',
#   'minutesighs',
#   'restseveral',
#   'notable',
#   'faces',
#   'turn',
#   'slum',
#   'sleepy',
#   'kevin',
#   'tighe',
#   'long',
#   'way',
#   'emergency',
#   'daysnick',
#   'mancuso',
#   'shows',
#   'sleepwalking',
#   'mode',
#   'take',
#   'checkno',
#   'rapperspleaseat',
#   'point',
#   'action',
#   'scenes',
#   'plots',
#   'predictable',
#   'recycled',
#   'generically',
#   'everits',
#   'stale',
#   'scene',
#   'seagal',
#   'needs',
#   'get',
#   'hang',
#   'uphe',
#   'gotten',
#   'ago'],
#  ['dont',
#   'mind',
#   'soundtrack',
#   'played',
#   'nowstill',
#   'debra',
#   'winger',
#   'always',
#   'interesting',
#   'earlier',
#   'role',
#   'quite',
#   'good',
#   'cissy',
#   'girl',
#   'wrong',
#   'side',
#   'tracks',
#   'lived',
#   'trailer',
#   'bud',
#   'travolta',
#   'replaced',
#   'time',
#   'city',
#   'slicker',
#   'madolyn',
#   'smith',
#   'rivali',
#   'agree',
#   'earlier',
#   'review',
#   'regarding',
#   'scott',
#   'glenn',
#   'used',
#   'plot',
#   'thrown',
#   'mix',
#   'create',
#   'suspense',
#   'story',
#   'predictable',
#   'contrivedalso',
#   'even',
#   'though',
#   'east',
#   'many',
#   'us',
#   'like',
#   'saturday',
#   'night',
#   'fever',
#   'moments',
#   'perpetual',
#   'stereotypes',
#   'beyond',
#   'criticism',
#   'pointworth',
#   'seeing',
#   'debra',
#   'winger',
#   'still',
#   'likable',
#   'never',
#   'hollywood',
#   'persona',
#   'subjected',
#   'many',
#   'actresses',
#   'today'],
#  ['wonderful',
#   'comedy',
#   'shortone',
#   'keatons',
#   'absolute',
#   'best',
#   'long',
#   'series',
#   'silly',
#   'mistakes',
#   'buster',
#   'mistaken',
#   'wanted',
#   'killer',
#   'result',
#   'film',
#   'consists',
#   'running',
#   'cops',
#   'one',
#   'detective',
#   'particular',
#   'generally',
#   'fan',
#   'movies',
#   'lot',
#   'chase',
#   'scenes',
#   'one',
#   'absolute',
#   'best',
#   'far',
#   'pure',
#   'athletic',
#   'acrobatic',
#   'ability',
#   'seen',
#   'wilder',
#   'stunts',
#   'none',
#   'star',
#   'limber',
#   'able',
#   'move',
#   'amazing',
#   'grace',
#   'particular',
#   'scene',
#   'runs',
#   'across',
#   'table',
#   'jumps',
#   'mans',
#   'shoulders',
#   'dives',
#   'transom',
#   'lithely',
#   'humanly',
#   'possible',
#   'plus',
#   'many',
#   'gags',
#   'funny',
#   'perfectly',
#   'timed',
#   'really',
#   'comes',
#   'believe',
#   'hes',
#   'actually',
#   'killed',
#   'someone',
#   'way',
#   'film',
#   'similar',
#   'cops',
#   'also',
#   'keaton',
#   'original',
#   'enough',
#   'enough',
#   'energy',
#   'make',
#   'worth',
#   'seeingthis',
#   'film',
#   'brilliant',
#   'keaton',
#   'short',
#   'think',
#   'probably',
#   'liked',
#   'even',
#   'playhousewhere',
#   'buster',
#   'plays',
#   'every',
#   'role',
#   'theater'],
#  ['really',
#   'disappointed',
#   'viewing',
#   'pinocchios',
#   'revenge',
#   'night',
#   'good',
#   'inclination',
#   'going',
#   'bad',
#   'one',
#   'didnt',
#   'think',
#   'itd',
#   'bad',
#   'turned',
#   'wooden',
#   'puppet',
#   'murdered',
#   'boy',
#   'falls',
#   'hands',
#   'attorneys',
#   'eightyearold',
#   'daughter',
#   'murderous',
#   'path',
#   'anyone',
#   'gets',
#   'way',
#   'puppet',
#   'little',
#   'girl',
#   'weve',
#   'seen',
#   'movies',
#   'like',
#   'ie',
#   'childs',
#   'play',
#   'series',
#   'way',
#   'far',
#   'better',
#   'however',
#   'good',
#   'see',
#   'actors',
#   'like',
#   'james',
#   'w',
#   'quinn',
#   'todd',
#   'allen',
#   'worked',
#   'kevin',
#   'tenney',
#   'event',
#   'encourage',
#   'viewers',
#   'check',
#   'night',
#   'demons',
#   'original',
#   'witchboard',
#   'titles',
#   'tend',
#   'bring',
#   'best',
#   'kevin',
#   'tenney'],
#  ['spoilers',
#   'spoilers',
#   'teen',
#   'slasher',
#   'flicks',
#   'suffering',
#   'drought',
#   'originality',
#   'awfully',
#   'seems',
#   'first',
#   'noble',
#   'premise',
#   'couldve',
#   'utilized',
#   'well',
#   'rejected',
#   'young',
#   'nerd',
#   'grows',
#   'stalks',
#   'murders',
#   'girls',
#   'tortured',
#   'hell',
#   'junior',
#   'high',
#   'cant',
#   'say',
#   'nothing',
#   'work',
#   'film',
#   'goes',
#   'motions',
#   'recent',
#   'slashers',
#   'everything',
#   'score',
#   'camera',
#   'angles',
#   'allow',
#   'us',
#   'predict',
#   'exactly',
#   'false',
#   'alarm',
#   'coming',
#   'exactly',
#   'killer',
#   'strike',
#   'know',
#   'pattern',
#   'stupid',
#   'slasher',
#   'movies',
#   'push',
#   'credibility',
#   'envelope',
#   'minute',
#   'let',
#   'ask',
#   'something',
#   'right',
#   'mind',
#   'going',
#   'surprise',
#   'friend',
#   'dark',
#   'dreary',
#   'morgue',
#   'middle',
#   'night',
#   'surprise',
#   'blue',
#   'shes',
#   'alone',
#   'surrounded',
#   'corpses',
#   'make',
#   'damn',
#   'sense',
#   'allvalentine',
#   'occasionally',
#   'innovative',
#   'one',
#   'good',
#   'shot',
#   'involves',
#   'butchering',
#   'denise',
#   'richards',
#   'character',
#   'gets',
#   'trapped',
#   'inside',
#   'pool',
#   'killer',
#   'pokes',
#   'chainsaw',
#   'theres',
#   'good',
#   'songs',
#   'soundtrack',
#   'including',
#   'one',
#   'cool',
#   'track',
#   'orgy',
#   'music',
#   'video',
#   'contained',
#   'special',
#   'features',
#   'section',
#   'dvdeven',
#   'acting',
#   'mediocre',
#   'best',
#   'actors',
#   'sleep',
#   'roles',
#   'course',
#   'david',
#   'boreanaz',
#   'often',
#   'stoic',
#   'even',
#   'portrayal',
#   'title',
#   'character',
#   'angel',
#   'denise',
#   'richards',
#   'fine',
#   'actress',
#   'though',
#   'keeps',
#   'stoneface',
#   'throughout',
#   'movievalentine',
#   'like',
#   'youd',
#   'expect',
#   'pretentious',
#   'implausible',
#   'forgettable',
#   'cheesy',
#   'without',
#   'good',
#   'scare',
#   'sight',
#   'dont',
#   'even',
#   'bothermy',
#   'score'],
#  ['satire',
#   'greed',
#   'money',
#   'greed',
#   'intentions',
#   'behind',
#   'fiasco',
#   'themes',
#   'pathetically',
#   'try',
#   'make',
#   'fun',
#   'jim',
#   'carreys',
#   'reign',
#   'certainly',
#   'short',
#   'lived',
#   'unbearable',
#   'presence',
#   'screen',
#   'insincerity',
#   'portrayal',
#   'nothing',
#   'short',
#   'creepy',
#   'produced',
#   'masterpiece',
#   'well',
#   'cant',
#   'blame',
#   'anyone',
#   'number',
#   'one',
#   'comedy',
#   'america',
#   'shout',
#   'desperate',
#   'tv',
#   'adds',
#   'course',
#   'jim',
#   'carrey',
#   'suppose',
#   'guarantee',
#   'full',
#   'houses',
#   'game',
#   'sound',
#   'angry',
#   'spent',
#   'sunny',
#   'afternoon',
#   'california',
#   'plus',
#   'tickets',
#   'parking',
#   'flat',
#   'cokes',
#   'etc',
#   'almost',
#   'bucks',
#   'thing',
#   'starring',
#   'produced',
#   'mr',
#   'carry',
#   'anymore',
#   'hear',
#   'anymore'],
#  ['definitely',
#   'worst',
#   'movie',
#   'ever',
#   'seen',
#   'somebody',
#   'tell',
#   'laughed',
#   'theres',
#   'single',
#   'hint',
#   'shadow',
#   'idea',
#   'three',
#   'leading',
#   'actors',
#   'pestilential',
#   'especially',
#   'one',
#   'think',
#   'aldo',
#   'sicily',
#   'cant',
#   'make',
#   'sicilian',
#   'accent',
#   'say',
#   'dreamlike',
#   'insertion',
#   'dracula',
#   'another',
#   'expedient',
#   'drawn',
#   'worst',
#   'cabaret',
#   'tradition',
#   'make',
#   'film',
#   'last',
#   'little',
#   'longer',
#   'massironi',
#   'littizzetto',
#   'socalled',
#   'movie',
#   'really',
#   'hard',
#   'rescue',
#   'would',
#   'given',
#   'lowest',
#   'mark',
#   'overestimate',
#   'one',
#   'mark'],
#  ['safely',
#   'admit',
#   'imdb',
#   'geek',
#   'phantom',
#   'lady',
#   'never',
#   'crack',
#   'film',
#   'noir',
#   'top',
#   'twenty',
#   'may',
#   'even',
#   'sneak',
#   'top',
#   'fifty',
#   'rather',
#   'discredit',
#   'film',
#   'good',
#   'many',
#   'classics',
#   'film',
#   'noir',
#   'genre',
#   'noted',
#   'phantom',
#   'lady',
#   'enough',
#   'strong',
#   'lasting',
#   'images',
#   'make',
#   'worthwhile',
#   'viewing',
#   'required',
#   'viewer',
#   'ability',
#   'get',
#   'beyond',
#   'dreadfully',
#   'slow',
#   'beginningthe',
#   'film',
#   'doesnt',
#   'get',
#   'cooking',
#   'kansas',
#   'ella',
#   'raines',
#   'sets',
#   'trying',
#   'prove',
#   'single',
#   'handedly',
#   'innocence',
#   'boss',
#   'scott',
#   'anderson',
#   'alan',
#   'curtis',
#   'convicted',
#   'murder',
#   'kansas',
#   'andersons',
#   'secretary',
#   'day',
#   'amateur',
#   'detective',
#   'night',
#   'novice',
#   'sleuth',
#   'quite',
#   'well',
#   'working',
#   'streets',
#   'new',
#   'york',
#   'night',
#   'little',
#   'little',
#   'starts',
#   'putting',
#   'pieces',
#   'murder',
#   'mystery',
#   'puzzle',
#   'together',
#   'honest',
#   'film',
#   'belongs',
#   'raines',
#   'due',
#   'presence',
#   'film',
#   'works',
#   'well',
#   'somehow',
#   'able',
#   'breathe',
#   'life',
#   'film',
#   'condemned',
#   'man',
#   'interesting',
#   'slightest',
#   'im',
#   'sure',
#   'splintered',
#   'dynamic',
#   'characterless',
#   'leading',
#   'man',
#   'becomes',
#   'fault',
#   'actor',
#   'director',
#   'clearly',
#   'something',
#   'becomes',
#   'terribly',
#   'wrong',
#   'filmas',
#   'interesting',
#   'raines',
#   'novice',
#   'detective',
#   'things',
#   'really',
#   'accelerate',
#   'another',
#   'hidden',
#   'gear',
#   'kansas',
#   'pays',
#   'late',
#   'night',
#   'visit',
#   'wandering',
#   'drummer',
#   'elisha',
#   'cook',
#   'jr',
#   'search',
#   'information',
#   'help',
#   'condemned',
#   'boss',
#   'drummer',
#   'paint',
#   'town',
#   'new',
#   'kind',
#   'red',
#   'visiting',
#   'night',
#   'jazz',
#   'clubs',
#   'trying',
#   'describe',
#   'scene',
#   'either',
#   'prove',
#   'injustice',
#   'scene',
#   'worse',
#   'yet',
#   'could',
#   'ruin',
#   'scene',
#   'together',
#   'youll',
#   'know',
#   'scene',
#   'last',
#   'cymbal',
#   'crash',
#   'finished',
#   'ringing',
#   'youre',
#   'lucky',
#   'enough',
#   'film',
#   'dvd',
#   'youll',
#   'likely',
#   'rewinding',
#   'scene',
#   'good',
#   'raines',
#   'scene',
#   'makes',
#   'film',
#   'noteworthy',
#   'mainly',
#   'scene',
#   'rate',
#   'phantom',
#   'lady',
#   'instead',
#   'part',
#   'film',
#   'comes',
#   'tepid',
#   'bland',
#   'great',
#   'scenes',
#   'one',
#   'magnificent',
#   'scene',
#   'drumsex',
#   'scene',
#   'separates',
#   'film',
#   'others',
#   'ilkand',
#   'like',
#   'said',
#   'film',
#   'never',
#   'go',
#   'wrong',
#   'vanilla',
#   'would',
#   'also',
#   'like',
#   'add',
#   'going',
#   'vanilla',
#   'safe',
#   'fall',
#   'back',
#   'choice',
#   'one',
#   'cant',
#   'decide',
#   'tastier',
#   'treat',
#   'clark',
#   'richards'],
#  ['rather',
#   'enjoyed',
#   'movie',
#   'ill',
#   'tell',
#   'right',
#   'mother',
#   'wouldnt',
#   'really',
#   'warped',
#   'little',
#   'dark',
#   'comedy',
#   'reads',
#   'like',
#   'fairy',
#   'tale',
#   'gone',
#   'awry',
#   'neat',
#   'treat',
#   'cameos',
#   'want',
#   'something',
#   'different',
#   'look'],
#  ['good',
#   'movie',
#   'last',
#   'picture',
#   'revealing',
#   'unknown',
#   'side',
#   'rock',
#   'illusions',
#   'fame',
#   'wellknown',
#   'rockers',
#   'getting',
#   'old',
#   'forgotten',
#   'music',
#   'good',
#   'sense',
#   'humour',
#   'ever',
#   'danced',
#   'bill',
#   'haleys',
#   'rock',
#   'around',
#   'clockanyway',
#   'still',
#   'crazy',
#   'probably',
#   'best',
#   'movie',
#   'rock',
#   'nroll',
#   'ever',
#   'seen',
#   'far',
#   'much',
#   'better',
#   'spinal',
#   'tap',
#   'instance',
#   'still',
#   'crazy',
#   'people',
#   'mature',
#   'different',
#   'point',
#   'view',
#   'rock',
#   'love',
#   'life',
#   'want',
#   'catch',
#   'crazy',
#   'youth',
#   'miss',
#   'much',
#   'beyond',
#   'story',
#   'see',
#   'characters',
#   'personality',
#   'weaknesses',
#   'dreams',
#   'like',
#   'anyone',
#   'usspend',
#   'good',
#   'time',
#   'watching',
#   'listen',
#   'awesome',
#   'soundtrack',
#   'finally',
#   'thinking',
#   'futurebye'],
#  ['caught',
#   'brief',
#   'run',
#   'philadelphia',
#   'theater',
#   'despite',
#   'local',
#   'provenance',
#   'relation',
#   'hometown',
#   'tragedy',
#   'namely',
#   'beating',
#   'death',
#   'eddie',
#   'polec',
#   'really',
#   'come',
#   'hard',
#   'movie',
#   'director',
#   'reasons',
#   'best',
#   'known',
#   'decided',
#   'shoot',
#   'entire',
#   'film',
#   'guerillastyle',
#   'nonstop',
#   'handheld',
#   'cameras',
#   'rapidfire',
#   'cuts',
#   'technique',
#   'might',
#   'work',
#   'scenes',
#   'jarring',
#   'violence',
#   'utterly',
#   'inappropriate',
#   'rest',
#   'material',
#   'makes',
#   'majority',
#   'film',
#   'stroll',
#   'sidewalk',
#   'brothertobrother',
#   'discussion',
#   'sofa',
#   'hell',
#   'even',
#   'kiss',
#   'firstdate',
#   'shot',
#   'cusinartstyle',
#   'distracting',
#   'viewer',
#   'ever',
#   'able',
#   'enter',
#   'drama',
#   'martin',
#   'also',
#   'undercuts',
#   'narrative',
#   'packing',
#   'far',
#   'many',
#   'topics',
#   'besides',
#   'birth',
#   'mob',
#   'violence',
#   'get',
#   'anorexia',
#   'alcoholism',
#   'divorce',
#   'racism',
#   'parental',
#   'abusedid',
#   'miss',
#   'anything',
#   'doubt',
#   'better',
#   'cast',
#   'betterfocused',
#   'direction',
#   'would',
#   'knit',
#   'threads',
#   'together',
#   'martin',
#   'surely',
#   'intended',
#   'demonstrate',
#   'one',
#   'moral',
#   'flaw',
#   'leads',
#   'sustains',
#   'host',
#   'othersbut',
#   'good',
#   'intentions',
#   'necessarily',
#   'great',
#   'film',
#   'make',
#   'sprawling',
#   'mess',
#   'martin',
#   'know',
#   'youre',
#   'town',
#   'im',
#   'man',
#   'really',
#   'amjust',
#   'better',
#   'job',
#   'next',
#   'time',
#   'like',
#   'two',
#   'plus',
#   'one'],
#  ['ive',
#   'always',
#   'loved',
#   'gone',
#   'wind',
#   'seen',
#   'numerous',
#   'times',
#   'however',
#   'ending',
#   'left',
#   'hanging',
#   'depressed',
#   'hopeless',
#   'feeling',
#   'finally',
#   'scarlett',
#   'ripley',
#   'took',
#   'us',
#   'plausible',
#   'satisfying',
#   'end',
#   'beginning',
#   'original',
#   'storyit',
#   'follows',
#   'someone',
#   'scarletts',
#   'obvious',
#   'intelligence',
#   'originally',
#   'written',
#   'would',
#   'eventually',
#   'grow',
#   'although',
#   'like',
#   'people',
#   'fell',
#   'love',
#   'scarlett',
#   'gwtw',
#   'tired',
#   'constant',
#   'insipid',
#   'infantiilism',
#   'point',
#   'exasperation',
#   'disappointed',
#   'mitchell',
#   'show',
#   'scarlett',
#   'using',
#   'obvious',
#   'intelligence',
#   'even',
#   'make',
#   'attempt',
#   'grow',
#   'emotionally',
#   'thankfully',
#   'someone',
#   'finally',
#   'isnt',
#   'nagging',
#   'immaturity',
#   'conflicted',
#   'beauty',
#   'intelligence',
#   'reason',
#   'rhett',
#   'finally',
#   'gave',
#   'first',
#   'place',
#   'think',
#   'ripley',
#   'excellent',
#   'job',
#   'describing',
#   'longoverdue',
#   'process',
#   'whalleykilmer',
#   'superb',
#   'job',
#   'portraying',
#   'joanne',
#   'wk',
#   'fire',
#   'exuberance',
#   'intelligent',
#   'sparkle',
#   'vivian',
#   'leigh',
#   'certainly',
#   'least',
#   'beautifulthere',
#   'always',
#   'one',
#   'clark',
#   'gable',
#   'however',
#   'pick',
#   'actor',
#   'thousands',
#   'ive',
#   'exposed',
#   'portray',
#   'biography',
#   'would',
#   'definitely',
#   'timothy',
#   'dalton',
#   'dalton',
#   'possesses',
#   'elegant',
#   'charm',
#   'gable',
#   'essential',
#   'rhetts',
#   'character',
#   'cant',
#   'imagine',
#   'anyone',
#   'else',
#   'could',
#   'come',
#   'closein',
#   'opinion',
#   'joanne',
#   'whalleykilmer',
#   'timothy',
#   'dalton',
#   'superbly',
#   'cast',
#   'actors',
#   'could',
#   'possibly',
#   'played',
#   'scarlett',
#   'rhett',
#   'think',
#   'performances',
#   'justice',
#   'late',
#   'actors',
#   'also',
#   'spirit',
#   'charactersi',
#   'enjoyed',
#   'whole',
#   'cast',
#   'julie',
#   'harris',
#   'usual',
#   'delightful',
#   'presence',
#   'jean',
#   'smart',
#   'adorable',
#   'kick',
#   'even',
#   'ashleys',
#   'character',
#   'nicely',
#   'played',
#   'stephen',
#   'collins',
#   'progression',
#   'relationship',
#   'scarlett',
#   'totally',
#   'believablethe',
#   'story',
#   'became',
#   'little',
#   'convoluted',
#   'ireland',
#   'life',
#   'still',
#   'found',
#   'entertainingall',
#   'thoroughly',
#   'enjoyed',
#   'fruits',
#   'ripleys',
#   'imagination',
#   'wish',
#   'id',
#   'written'],
#  ['one',
#   'successful',
#   'shows',
#   'television',
#   'history',
#   'back',
#   'admit',
#   'never',
#   'got',
#   'original',
#   'show',
#   'okay',
#   'never',
#   'watched',
#   'new',
#   'show',
#   'impressivescifi',
#   'premiered',
#   'first',
#   'two',
#   'episodes',
#   'rose',
#   'end',
#   'world',
#   'weekend',
#   'meet',
#   'rose',
#   'twentysomething',
#   'clerk',
#   'chased',
#   'remote',
#   'controlled',
#   'mannequins',
#   'rescued',
#   'mysterious',
#   'stranger',
#   'calls',
#   'doctor',
#   'using',
#   'internet',
#   'finds',
#   'conspiracy',
#   'buff',
#   'warns',
#   'wherever',
#   'doctor',
#   'goes',
#   'death',
#   'follows',
#   'geeky',
#   'boyfriend',
#   'mickey',
#   'replaced',
#   'impostor',
#   'doctor',
#   'informs',
#   'plot',
#   'use',
#   'earth',
#   'breeding',
#   'ground',
#   'plastic',
#   'monsters',
#   'doctor',
#   'fighting',
#   'across',
#   'space',
#   'time',
#   'traveling',
#   'tardis',
#   'disguised',
#   'sstyle',
#   'police',
#   'call',
#   'boxshe',
#   'helps',
#   'save',
#   'worldthere',
#   'wouldnt',
#   'show',
#   'otherwiseand',
#   'decides',
#   'join',
#   'puts',
#   'life',
#   'danger',
#   'distraught',
#   'questions',
#   'whether',
#   'company',
#   'worth',
#   'riskalthough',
#   'special',
#   'effects',
#   'kinda',
#   'lame',
#   'scenes',
#   'bit',
#   'choppy',
#   'doctor',
#   'two',
#   'episodes',
#   'aired',
#   'us',
#   'smart',
#   'wellwritten',
#   'work',
#   'apparently',
#   'second',
#   'season',
#   'already',
#   'aired',
#   'uk',
#   'predict',
#   'success'],
#  ['hard',
#   'believe',
#   'perhaps',
#   'film',
#   'denounced',
#   'immoral',
#   'pulpits',
#   'film',
#   'produced',
#   'prior',
#   'imposition',
#   'bluenose',
#   'hayes',
#   'code',
#   'yes',
#   'indeed',
#   'priests',
#   'actually',
#   'told',
#   'flocks',
#   'anyone',
#   'went',
#   'see',
#   'film',
#   'thereby',
#   'committing',
#   'mortal',
#   'sinim',
#   'making',
#   'several',
#   'reasons',
#   'followsitem',
#   'jane',
#   'likes',
#   'sex',
#   'tarzan',
#   'shown',
#   'waking',
#   'one',
#   'morning',
#   'treetop',
#   'shelter',
#   'stretches',
#   'sensuously',
#   'coquettish',
#   'look',
#   'says',
#   'tarzan',
#   'youve',
#   'bad',
#   'boy',
#   'theyve',
#   'sex',
#   'theyve',
#   'kinky',
#   'sex',
#   'years',
#   'later',
#   'hays',
#   'code',
#   'people',
#   'especially',
#   'women',
#   'werent',
#   'supposed',
#   'depicted',
#   'enjoying',
#   'sexitem',
#   'jane',
#   'prefers',
#   'guileless',
#   'wise',
#   'resourceful',
#   'savage',
#   'tarzan',
#   'civilized',
#   'respectable',
#   'ninetofive',
#   'man',
#   'holt',
#   'holt',
#   'first',
#   'wows',
#   'pretty',
#   'dress',
#   'london',
#   'wavers',
#   'bit',
#   'holt',
#   'tries',
#   'kill',
#   'tarzan',
#   'holt',
#   'jane',
#   'believe',
#   'hes',
#   'dead',
#   'wavers',
#   'lot',
#   'realizes',
#   'man',
#   'much',
#   'alive',
#   'attractions',
#   'civilization',
#   'vanish',
#   'tarzans',
#   'janes',
#   'relationship',
#   'egalitarian',
#   'lacks',
#   'civilized',
#   'insecurity',
#   'would',
#   'compel',
#   'assert',
#   'head',
#   'wife',
#   'boot',
#   'lacks',
#   'many',
#   'civilized',
#   'hangups',
#   'example',
#   'jealousy',
#   'holt',
#   'buddy',
#   'arrive',
#   'tarzan',
#   'greets',
#   'cordially',
#   'knowing',
#   'perfectly',
#   'well',
#   'holt',
#   'janes',
#   'old',
#   'flame',
#   'holt',
#   'gets',
#   'dolled',
#   'london',
#   'dress',
#   'slowdancing',
#   'portable',
#   'phonograph',
#   'tarzan',
#   'drops',
#   'tree',
#   'draws',
#   'knife',
#   'jealous',
#   'nope',
#   'hes',
#   'merely',
#   'cautious',
#   'toward',
#   'weird',
#   'music',
#   'machine',
#   'since',
#   'hes',
#   'never',
#   'seen',
#   'one',
#   'explained',
#   'hes',
#   'coolitem',
#   'civilized',
#   'holt',
#   'dirty',
#   'minded',
#   'savage',
#   'tarzan',
#   'innocently',
#   'sexy',
#   'jane',
#   'slips',
#   'holts',
#   'lamplit',
#   'tent',
#   'holt',
#   'gets',
#   'watching',
#   'silhouette',
#   'changes',
#   'fancy',
#   'dress',
#   'contrast',
#   'tarzan',
#   'playfully',
#   'pulls',
#   'dress',
#   'kicks',
#   'swimming',
#   'hole',
#   'dives',
#   'follows',
#   'tastefully',
#   'erotic',
#   'nude',
#   'scene',
#   'cinema',
#   'pair',
#   'spends',
#   'five',
#   'minutes',
#   'lovely',
#   'water',
#   'balletthe',
#   'scene',
#   'filmed',
#   'three',
#   'versionsclothed',
#   'topless',
#   'nudethe',
#   'scene',
#   'cut',
#   'prior',
#   'films',
#   'release',
#   'nude',
#   'version',
#   'restored',
#   'video',
#   'available',
#   'jane',
#   'emerges',
#   'cheetah',
#   'chimp',
#   'steals',
#   'dress',
#   'tease',
#   'jane',
#   'makes',
#   'clear',
#   'irritation',
#   'proximity',
#   'civilized',
#   'men',
#   'hangups',
#   'universal',
#   'prurience',
#   'dear',
#   'hearts',
#   'seminarians',
#   'nowhere',
#   'thats',
#   'another',
#   'reason',
#   'hung',
#   'regarded',
#   'film',
#   'sinful',
#   'item',
#   'notion',
#   'man',
#   'crown',
#   'creation',
#   'animals',
#   'mans',
#   'use',
#   'comfort',
#   'takes',
#   'severe',
#   'beating',
#   'holt',
#   'buddy',
#   'want',
#   'guided',
#   'elephant',
#   'graveyard',
#   'scoop',
#   'ivory',
#   'take',
#   'home',
#   'want',
#   'tarzan',
#   'guide',
#   'said',
#   'graveyard',
#   'reader',
#   'thinking',
#   'fat',
#   'chance',
#   'youre',
#   'right',
#   'hes',
#   'shocked',
#   'exclaims',
#   'elephants',
#   'sleep',
#   'explains',
#   'everything',
#   'jane',
#   'explains',
#   'tarzans',
#   'feelings',
#   'two',
#   'gentlemen',
#   'find',
#   'ridiculous',
#   'item',
#   'jane',
#   'excivilized',
#   'woman',
#   'far',
#   'resourceful',
#   'two',
#   'civilized',
#   'men',
#   'accompanies',
#   'holt',
#   'buddy',
#   'blow',
#   'find',
#   'besieged',
#   'hostile',
#   'tribes',
#   'wild',
#   'animals',
#   'jane',
#   'maintains',
#   'cool',
#   'boys',
#   'panic',
#   'takes',
#   'charge',
#   'barks',
#   'orders',
#   'passes',
#   'riflesitem',
#   'janes',
#   'costume',
#   'sort',
#   'poncho',
#   'nothing',
#   'underneath',
#   'original',
#   'idea',
#   'topless',
#   'foliage',
#   'artistically',
#   'blocking',
#   'nipples',
#   'indeed',
#   'case',
#   'one',
#   'brief',
#   'scenelastly',
#   'several',
#   'men',
#   'cloth',
#   'complained',
#   'film',
#   'called',
#   'tarzan',
#   'mate',
#   'rather',
#   'tarzan',
#   'wife',
#   'commentof',
#   'course',
#   'tarzan',
#   'nursed',
#   'back',
#   'health',
#   'ape',
#   'friends',
#   'comes',
#   'rescue',
#   'routs',
#   'white',
#   'hunters',
#   'induces',
#   'pack',
#   'elephants',
#   'african',
#   'bearers',
#   'return',
#   'ivory',
#   'stole',
#   'sacred',
#   'place',
#   'whence',
#   'came',
#   'endso',
#   'utterly',
#   'subversive',
#   'film',
#   'like',
#   'films',
#   'complex',
#   'interesting',
#   'women',
#   'see',
#   'eg',
#   'possessed',
#   'rita',
#   'hayworth',
#   'raymond',
#   'massey',
#   'constituted',
#   'flowing',
#   'genre',
#   'early',
#   'brought',
#   'abrupt',
#   'end',
#   'adoption',
#   'hays',
#   'code',
#   'joie',
#   'de',
#   'vivre',
#   'film',
#   'best',
#   'expressed',
#   'janes',
#   'soprano',
#   'version',
#   'famous',
#   'tarzan',
#   'yell',
#   'nice',
#   'touch',
#   'unfortunately',
#   'abandoned',
#   'future',
#   'productionslets',
#   'hear',
#   'artistic',
#   'freedom',
#   'feminist',
#   'jane',
#   'sex'],
#  ['family',
#   'guy',
#   'probably',
#   'ballsy',
#   'sitcom',
#   'ever',
#   'produced',
#   'relentlessly',
#   'skewers',
#   'everything',
#   'think',
#   'tv',
#   'shows',
#   'family',
#   'drama',
#   'best',
#   'one',
#   'tv',
#   'shows',
#   'today',
#   'thats',
#   'actually',
#   'funnythe',
#   'show',
#   'revolves',
#   'around',
#   'griffins',
#   'peter',
#   'obese',
#   'father',
#   'whose',
#   'schemes',
#   'limited',
#   'lack',
#   'intelligence',
#   'lois',
#   'mother',
#   'less',
#   'head',
#   'family',
#   'even',
#   'though',
#   'peter',
#   'considers',
#   'chris',
#   'fat',
#   'teenage',
#   'son',
#   'brains',
#   'dad',
#   'meg',
#   'black',
#   'sheep',
#   'family',
#   'everyones',
#   'jokes',
#   'stewie',
#   'baby',
#   'plans',
#   'killing',
#   'mother',
#   'taking',
#   'world',
#   'brian',
#   'family',
#   'dog',
#   'frequently',
#   'voice',
#   'reason',
#   'frequently',
#   'corruptedfamily',
#   'guy',
#   'employs',
#   'many',
#   'tactics',
#   'get',
#   'laughs',
#   'audience',
#   'notable',
#   'frequent',
#   'cutaways',
#   'spoof',
#   'said',
#   'effective',
#   'impeccable',
#   'timing',
#   'play',
#   'family',
#   'guy',
#   'uses',
#   'spoofs',
#   'get',
#   'humor',
#   'well',
#   'commonly',
#   'tv',
#   'shows',
#   'really',
#   'makes',
#   'show',
#   'great',
#   'person',
#   'doesnt',
#   'familiar',
#   'spoofing',
#   'im',
#   'sure',
#   'would',
#   'help',
#   'material',
#   'funny',
#   'enough',
#   'right',
#   'show',
#   'doesnt',
#   'stop',
#   'spoof',
#   'everything',
#   'skewers',
#   'spoofs',
#   'show',
#   'filled',
#   'offcolor',
#   'humor',
#   'reason',
#   'people',
#   'arent',
#   'arms',
#   'show',
#   'probably',
#   'makes',
#   'fun',
#   'every',
#   'race',
#   'sex',
#   'generality',
#   'equally',
#   'nothing',
#   'sacred',
#   'one',
#   'nothing',
#   'immune',
#   'family',
#   'guys',
#   'satirical',
#   'jabsputting',
#   'musical',
#   'numbers',
#   'film',
#   'takes',
#   'lot',
#   'time',
#   'effort',
#   'big',
#   'risk',
#   'family',
#   'guy',
#   'contains',
#   'great',
#   'songs',
#   'wellwritten',
#   'performed',
#   'course',
#   'hilarious',
#   'perhaps',
#   'famous',
#   'one',
#   'freakin',
#   'fcc',
#   'catchy',
#   'hysterical',
#   'hits',
#   'ratings',
#   'board',
#   'hurtsthe',
#   'voice',
#   'characterizations',
#   'right',
#   'money',
#   'seth',
#   'mcfarlane',
#   'tremendously',
#   'talented',
#   'provides',
#   'voices',
#   'peter',
#   'brian',
#   'natural',
#   'voice',
#   'stewie',
#   'voices',
#   'consistent',
#   'creative',
#   'alter',
#   'pitch',
#   'really',
#   'seems',
#   'spoken',
#   'three',
#   'different',
#   'actors',
#   'alex',
#   'borstein',
#   'brings',
#   'nasally',
#   'drawl',
#   'lois',
#   'perfect',
#   'character',
#   'seth',
#   'green',
#   'unrecognizable',
#   'chris',
#   'looked',
#   'imdb',
#   'would',
#   'never',
#   'known',
#   'lacey',
#   'chabert',
#   'originated',
#   'character',
#   'meg',
#   'good',
#   'mila',
#   'kunis',
#   'really',
#   'elevated',
#   'character',
#   'sharp',
#   'voice',
#   'kunis',
#   'gives',
#   'meg',
#   'new',
#   'sharper',
#   'edge',
#   'didnt',
#   'chabertfamily',
#   'guy',
#   'compared',
#   'simpsons',
#   'thats',
#   'entirely',
#   'understandable',
#   'produced',
#   'fox',
#   'satires',
#   'bluecollar',
#   'life',
#   'simpsons',
#   'good',
#   'family',
#   'guy',
#   'contains',
#   'sharper',
#   'edge',
#   'show',
#   'utterly',
#   'fearless',
#   'real',
#   'sacred',
#   'cow',
#   'show',
#   'lampoons',
#   'handicaps',
#   'physical',
#   'mental',
#   'ethnicities',
#   'tv',
#   'shows',
#   'movies',
#   'celebrities',
#   'politicians',
#   'religion',
#   'especially',
#   'catholicism',
#   'drug',
#   'use',
#   'addiction',
#   'sexual',
#   'humor',
#   'kinds',
#   'including',
#   'sm',
#   'thats',
#   'beyond',
#   'description',
#   'everything',
#   'family',
#   'guy',
#   'throws',
#   'audience',
#   'works',
#   'whole',
#   'show',
#   'consistently',
#   'amusing',
#   'frequently',
#   'hilariousif',
#   'theres',
#   'flaw',
#   'family',
#   'guy',
#   'jokes',
#   'run',
#   'far',
#   'long',
#   'sometimes',
#   'particularly',
#   'awkward',
#   'moment',
#   'jokes',
#   'sequences',
#   'stretched',
#   'long',
#   'cease',
#   'become',
#   'funny',
#   'becomes',
#   'irritating',
#   'long',
#   'fastforward',
#   'button',
#   'warranted',
#   'effective',
#   'seconds',
#   'show',
#   'sometimes',
#   'stretches',
#   'beyond',
#   'two',
#   'minutes',
#   'one',
#   'could',
#   'argue',
#   'show',
#   'rewrites',
#   'rules',
#   'suit',
#   'plot',
#   'often',
#   'example',
#   'brian',
#   'frequently',
#   'acts',
#   'like',
#   'person',
#   'still',
#   'acts',
#   'like',
#   'dog',
#   'story',
#   'requires',
#   'thats',
#   'problem',
#   'show',
#   'still',
#   'workssome',
#   'people',
#   'argued',
#   'show',
#   'stopped',
#   'funny',
#   'agree',
#   'edgy',
#   'used',
#   'think',
#   'blame',
#   'lies',
#   'fox',
#   'mcfarlane',
#   'crew',
#   'show',
#   'originated',
#   'fox',
#   'lackluster',
#   'ratings',
#   'viewer',
#   'turnout',
#   'canceled',
#   'however',
#   'dvd',
#   'sales',
#   'large',
#   'enough',
#   'picked',
#   'adult',
#   'swim',
#   'show',
#   'became',
#   'instant',
#   'success',
#   'bought',
#   'fox',
#   'however',
#   'show',
#   'big',
#   'fox',
#   'afraid',
#   'let',
#   'writers',
#   'experiment',
#   'try',
#   'new',
#   'things',
#   'still',
#   'funny',
#   'humor',
#   'fresh',
#   'edgydefinitely',
#   'check',
#   'show',
#   'awesome'],
#  ['yes',
#   'art',
#   'successfully',
#   'make',
#   'slow',
#   'paced',
#   'thrillerthe',
#   'story',
#   'unfolds',
#   'nice',
#   'volumes',
#   'dont',
#   'even',
#   'notice',
#   'happeningfine',
#   'performance',
#   'robin',
#   'williams',
#   'sexuality',
#   'angles',
#   'film',
#   'seem',
#   'unnecessary',
#   'probably',
#   'affect',
#   'much',
#   'enjoy',
#   'film',
#   'however',
#   'core',
#   'plot',
#   'engaging',
#   'movie',
#   'doesnt',
#   'rush',
#   'onto',
#   'still',
#   'grips',
#   'enough',
#   'keep',
#   'wondering',
#   'direction',
#   'good',
#   'use',
#   'lights',
#   'achieve',
#   'desired',
#   'affects',
#   'suspense',
#   'unexpectedness',
#   'goodvery',
#   'nice',
#   'time',
#   'watch',
#   'looking',
#   'lay',
#   'back',
#   'hear',
#   'thrilling',
#   'short',
#   'story'],
#  ['remember',
#   'originally',
#   'seeing',
#   'film',
#   'radio',
#   'city',
#   'music',
#   'hall',
#   'came',
#   'didnt',
#   'really',
#   'understand',
#   'humor',
#   'back',
#   'movie',
#   'make',
#   'laugh',
#   'loudwith',
#   'due',
#   'respect',
#   'george',
#   'burns',
#   'rip',
#   'walter',
#   'matthau',
#   'really',
#   'deserved',
#   'oscar',
#   'film',
#   'performance',
#   'amazinggiven',
#   'fact',
#   'years',
#   'younger',
#   'character',
#   'willie',
#   'clark',
#   'mannerisms',
#   'firstrate',
#   'know',
#   'kind',
#   'songs',
#   'wrote',
#   'sht',
#   'speaking',
#   'spanishspeaking',
#   'guy',
#   'front',
#   'desk',
#   'enchilada',
#   'absolutely',
#   'hilariouskudos',
#   'richard',
#   'benjamin',
#   'played',
#   'straight',
#   'man',
#   'matthaui',
#   'wish',
#   'dvd',
#   'vhs',
#   'recording',
#   'getting',
#   'bit',
#   'oldi',
#   'interest',
#   'seeing',
#   'remake',
#   'woody',
#   'allen',
#   'way',
#   'match',
#   'original'],
#  ['first',
#   'hate',
#   'moronic',
#   'rappers',
#   'couldnt',
#   'act',
#   'gun',
#   'pressed',
#   'foreheads',
#   'curse',
#   'shoot',
#   'acting',
#   'like',
#   'cliche',
#   'version',
#   'gangstersthe',
#   'movie',
#   'doesnt',
#   'take',
#   'five',
#   'minutes',
#   'explain',
#   'going',
#   'already',
#   'warehouse',
#   'single',
#   'sympathetic',
#   'character',
#   'movie',
#   'except',
#   'homeless',
#   'guy',
#   'also',
#   'one',
#   'half',
#   'brainbill',
#   'paxton',
#   'william',
#   'sadler',
#   'hill',
#   'billies',
#   'sadlers',
#   'character',
#   'much',
#   'villain',
#   'gangsters',
#   'didnt',
#   'like',
#   'right',
#   'startthe',
#   'movie',
#   'filled',
#   'pointless',
#   'violence',
#   'walter',
#   'hills',
#   'specialty',
#   'people',
#   'falling',
#   'windows',
#   'glass',
#   'flying',
#   'everywhere',
#   'pretty',
#   'much',
#   'plot',
#   'big',
#   'problem',
#   'root',
#   'noone',
#   'everybody',
#   'dies',
#   'except',
#   'paxton',
#   'homeless',
#   'guy',
#   'everybody',
#   'get',
#   'deservethe',
#   'two',
#   'black',
#   'people',
#   'act',
#   'homeless',
#   'guy',
#   'junkie',
#   'theyre',
#   'actors',
#   'profession',
#   'annoying',
#   'ugly',
#   'brain',
#   'dead',
#   'rappersstay',
#   'away',
#   'crap',
#   'watch',
#   'hours',
#   'instead',
#   'lest',
#   'characters',
#   'care',
#   'sense',
#   'humor',
#   'nothing',
#   'real',
#   'actors',
#   'cast'],
#  ['apolitical',
#   'musicians',
#   'eva',
#   'liv',
#   'ullmann',
#   'jan',
#   'rosenberg',
#   'max',
#   'von',
#   'sydow',
#   'married',
#   'seven',
#   'years',
#   'live',
#   'small',
#   'farm',
#   'remote',
#   'island',
#   'escape',
#   'civil',
#   'war',
#   'continent',
#   'provide',
#   'lingenberry',
#   'couple',
#   'costumers',
#   'raise',
#   'money',
#   'buy',
#   'supplies',
#   'love',
#   'eva',
#   'twenty',
#   'years',
#   'old',
#   'wants',
#   'baby',
#   'reluctant',
#   'jan',
#   'weak',
#   'sensitive',
#   'man',
#   'want',
#   'children',
#   'rebels',
#   'arrive',
#   'island',
#   'peaceful',
#   'calm',
#   'lives',
#   'turn',
#   'hell',
#   'get',
#   'middle',
#   'accusations',
#   'sides',
#   'colonel',
#   'jacobi',
#   'gunnar',
#   'bjrnstrand',
#   'stalks',
#   'eva',
#   'jan',
#   'changes',
#   'behavior',
#   'becomes',
#   'brutal',
#   'man',
#   'love',
#   'affection',
#   'feel',
#   'change',
#   'hatred',
#   'indifferenceshame',
#   'antiwar',
#   'movie',
#   'master',
#   'ingmar',
#   'bergman',
#   'focused',
#   'eyes',
#   'couple',
#   'artists',
#   'apolitical',
#   'listen',
#   'news',
#   'war',
#   'arrives',
#   'lands',
#   'love',
#   'friendship',
#   'affection',
#   'destroyed',
#   'senseless',
#   'soldiers',
#   'liv',
#   'ullmann',
#   'max',
#   'von',
#   'sydow',
#   'topnotch',
#   'performances',
#   'usual',
#   'recall',
#   'seeing',
#   'breast',
#   'liv',
#   'ullmann',
#   'movie',
#   'process',
#   'brutalization',
#   'pacific',
#   'sensitive',
#   'jan',
#   'rosenberg',
#   'war',
#   'impressive',
#   'bleak',
#   'open',
#   'conclusion',
#   'pessimist',
#   'adequate',
#   'dramatic',
#   'story',
#   'vote',
#   'ninetitle',
#   'brazil',
#   'vergonha',
#   'shame'],
#  ['pitch',
#   'black',
#   'complete',
#   'shock',
#   'first',
#   'saw',
#   'back',
#   'previous',
#   'years',
#   'repeatedly',
#   'disappointed',
#   'lame',
#   'scifi',
#   'movies',
#   'ex',
#   'starship',
#   'troopers',
#   'thought',
#   'movie',
#   'wouldnt',
#   'different',
#   'plainly',
#   'put',
#   'movie',
#   'freaked',
#   'good',
#   'way',
#   'wasnt',
#   'aware',
#   'still',
#   'afraid',
#   'dark',
#   'till',
#   'watched',
#   'movie',
#   'must',
#   'buried',
#   'fear',
#   'back',
#   'subconscious',
#   'kid',
#   'rightfully',
#   'deserves',
#   'stay',
#   'therethe',
#   'alien',
#   'creatures',
#   'sent',
#   'shivers',
#   'spine',
#   'individuals',
#   'designed',
#   'twisted',
#   'brilliant',
#   'creative',
#   'imagination',
#   'come',
#   'something',
#   'impressive',
#   'grotesque',
#   'loved',
#   'writers',
#   'gave',
#   'main',
#   'character',
#   'history',
#   'showed',
#   'flaws',
#   'strengths',
#   'without',
#   'much',
#   'confusionriddicks',
#   'vin',
#   'diesel',
#   'gift',
#   'escaping',
#   'impossible',
#   'situation',
#   'putting',
#   'hell',
#   'fight',
#   'jaw',
#   'dropping',
#   'first',
#   'figure',
#   'coldly',
#   'intelligent',
#   'villain',
#   'brief',
#   'moments',
#   'see',
#   'something',
#   'humane',
#   'behind',
#   'animal',
#   'side',
#   'soon',
#   'discover',
#   'something',
#   'maliciously',
#   'devious',
#   'certainly',
#   'keeps',
#   'guessing',
#   'right',
#   'end',
#   'didnt',
#   'know',
#   'whether',
#   'despise',
#   'admire',
#   'hes',
#   'definitely',
#   'lovehate',
#   'type',
#   'characterjohns',
#   'cole',
#   'hauser',
#   'perfect',
#   'example',
#   'character',
#   'puts',
#   'good',
#   'front',
#   'need',
#   'greed',
#   'shows',
#   'real',
#   'intentions',
#   'hes',
#   'willing',
#   'survive',
#   'johns',
#   'knack',
#   'knowing',
#   'buttons',
#   'push',
#   'right',
#   'words',
#   'say',
#   'makes',
#   'devious',
#   'riddickfry',
#   'radha',
#   'mitchell',
#   'character',
#   'johns',
#   'nicely',
#   'expressed',
#   'looked',
#   'thine',
#   'ass',
#   'first',
#   'considering',
#   'consequences',
#   'whats',
#   'endearing',
#   'quickly',
#   'realizes',
#   'errors',
#   'ways',
#   'tries',
#   'desperately',
#   'pay',
#   'penance',
#   'even',
#   'endangering',
#   'life',
#   'others',
#   'discarded',
#   'human',
#   'values',
#   'went',
#   'dark',
#   'hills',
#   'runningjack',
#   'rhiana',
#   'griffith',
#   'simply',
#   'wanted',
#   'hero',
#   'first',
#   'one',
#   'whole',
#   'group',
#   'look',
#   'hero',
#   'riddick',
#   'childs',
#   'eye',
#   'good',
#   'seen',
#   'thick',
#   'clouds',
#   'evil',
#   'thought',
#   'absolutely',
#   'priceless',
#   'jack',
#   'shaves',
#   'head',
#   'ode',
#   'riddick',
#   'know',
#   'say',
#   'imitation',
#   'best',
#   'form',
#   'flatteryimam',
#   'keith',
#   'david',
#   'like',
#   'jack',
#   'ability',
#   'see',
#   'good',
#   'evil',
#   'uses',
#   'philosophy',
#   'carry',
#   'hardships',
#   'meets',
#   'time',
#   'permits',
#   'rationally',
#   'grieves',
#   'losses',
#   'soldiers',
#   'way',
#   'served',
#   'morale',
#   'booster',
#   'survivors',
#   'even',
#   'though',
#   'characters',
#   'acted',
#   'though',
#   'werent',
#   'listeningthe',
#   'casting',
#   'movie',
#   'positively',
#   'perfect',
#   'actor',
#   'shined',
#   'brightly',
#   'role',
#   'talents',
#   'blended',
#   'wonderfully',
#   'onscreenthis',
#   'movie',
#   'may',
#   'small',
#   'budget',
#   'directors',
#   'leadership',
#   'actors',
#   'performances',
#   'made',
#   'movie',
#   'work',
#   'allowed',
#   'audience',
#   'use',
#   'imagination',
#   'instead',
#   'letting',
#   'outrageously',
#   'expensive',
#   'special',
#   'effects',
#   'work',
#   'movie',
#   'definite',
#   'scifi',
#   'classic',
#   'watch',
#   'judge',
#   'open',
#   'mind',
#   'well',
#   'worth'],
#  ['sad',
#   'find',
#   'film',
#   'worth',
#   'watching',
#   'russian',
#   'disgusted',
#   'nothing',
#   'film',
#   'deserves',
#   'praise',
#   'except',
#   'cinematography',
#   'however',
#   'one',
#   'find',
#   'beauty',
#   'death',
#   'perversion',
#   'think',
#   'film',
#   'poorly',
#   'designed',
#   'directed',
#   'nothing',
#   'irritating',
#   'even',
#   'enraging',
#   'shameless',
#   'speculation',
#   'art',
#   'call',
#   'garbage',
#   'art',
#   'balabanov',
#   'wanted',
#   'shock',
#   'viewers',
#   'pervasive',
#   'evil',
#   'succeeded',
#   'creating',
#   'hopelessly',
#   'dark',
#   'film',
#   'biggest',
#   'shock',
#   'balabanovs',
#   'primitive',
#   'directorial',
#   'work',
#   'would',
#   'never',
#   'advise',
#   'friends',
#   'watch',
#   'huge',
#   'disappointment'],
#  ['considering',
#   'films',
#   'reputation',
#   'truly',
#   'worst',
#   'worst',
#   'looking',
#   'forward',
#   'watching',
#   'woods',
#   'crappus',
#   'opus',
#   'word',
#   'necessarily',
#   'inept',
#   'woods',
#   'ive',
#   'watched',
#   'however',
#   'reefer',
#   'madness',
#   'school',
#   'filmmaking',
#   'glen',
#   'glenda',
#   'doesnt',
#   'come',
#   'across',
#   'readily',
#   'enjoyable',
#   'genre',
#   'effortsalso',
#   'surely',
#   'emerges',
#   'horror',
#   'legend',
#   'bela',
#   'lugosis',
#   'nadir',
#   'first',
#   'three',
#   'collaborations',
#   'director',
#   'one',
#   'wonders',
#   'whether',
#   'really',
#   'aware',
#   'kind',
#   'film',
#   'considering',
#   'actors',
#   'history',
#   'heavy',
#   'medication',
#   'sheer',
#   'senselessness',
#   'cameo',
#   'besides',
#   'lugosis',
#   'idiosyncratic',
#   'delivery',
#   'perhaps',
#   'awkward',
#   'herethough',
#   'woods',
#   'script',
#   'mostly',
#   'blame',
#   'given',
#   'impossible',
#   'dialogue',
#   'repeated',
#   'nonsensical',
#   'allusions',
#   'puppydog',
#   'tails',
#   'big',
#   'fat',
#   'snails',
#   'handed',
#   'ailing',
#   'star',
#   'way',
#   'wood',
#   'plays',
#   'central',
#   'role',
#   'pseudonym',
#   'daniel',
#   'davis',
#   'worthless',
#   'area',
#   'proves',
#   'allround',
#   'dog',
#   'dolores',
#   'fuller',
#   'wife',
#   'costar',
#   'similarly',
#   'untalented',
#   'would',
#   'also',
#   'appear',
#   'jail',
#   'bait',
#   'least',
#   'image',
#   'latter',
#   'finally',
#   'lets',
#   'glen',
#   'wear',
#   'angora',
#   'sweater',
#   'give',
#   'tim',
#   'burtons',
#   'affectionate',
#   'biopic',
#   'ed',
#   'wood',
#   'famous',
#   'poster',
#   'incidentally',
#   'latter',
#   'film',
#   'features',
#   'presumably',
#   'fictionalized',
#   'meeting',
#   'wood',
#   'orson',
#   'welles',
#   'well',
#   'intents',
#   'purposes',
#   'glen',
#   'glenda',
#   'constitutes',
#   'ed',
#   'woods',
#   'citizen',
#   'kane',
#   'given',
#   'gleeful',
#   'propensity',
#   'gimmicky',
#   'narrative',
#   'techniques',
#   'fact',
#   'barest',
#   'thread',
#   'plot',
#   'padded',
#   'stock',
#   'footage',
#   'galore',
#   'many',
#   'irrelevant',
#   'bewildering',
#   'instances',
#   'sm',
#   'inane',
#   'dream',
#   'sequences',
#   'highlighted',
#   'presence',
#   'impish',
#   'demon',
#   'sporting',
#   'outrageous',
#   'bushy',
#   'eyebrows',
#   'would',
#   'make',
#   'martin',
#   'scorsese',
#   'weep',
#   'envy',
#   'films',
#   'sincere',
#   'attempt',
#   'plea',
#   'tolerance',
#   'psychological',
#   'probing',
#   'afflictionphenomenon',
#   'transvestism',
#   'however',
#   'sabotaged',
#   'every',
#   'turn',
#   'sheer',
#   'amateurishness',
#   'approachfor',
#   'worth',
#   'edition',
#   'watched',
#   'extended',
#   'reissue',
#   'version',
#   'included',
#   'six',
#   'minutes',
#   'depraved',
#   'footage',
#   'directed',
#   'w',
#   'merle',
#   'connell',
#   'censored',
#   'original',
#   'release',
#   'furthermore',
#   'copy',
#   'went',
#   'outofsynch',
#   'every',
#   'often',
#   'forced',
#   'rewind',
#   'slightly',
#   'get',
#   'audio',
#   'back',
#   'track',
#   'though',
#   'thankfully',
#   'fault',
#   'source',
#   'conversion',
#   'divx',
#   'opposed',
#   'film'],
#  ['film',
#   'makes',
#   'much',
#   'sense',
#   'ozzie',
#   'harriet',
#   'father',
#   'knows',
#   'best',
#   'episode',
#   'old',
#   'copy',
#   'readers',
#   'digest',
#   'circa',
#   'would',
#   'provide',
#   'insight',
#   'modern',
#   'life',
#   'relationship',
#   'father',
#   'daughter',
#   'weird',
#   'concoctioni',
#   'surprised',
#   'diane',
#   'keaton',
#   'appears',
#   'sleepwalk',
#   'film',
#   'given',
#   'films',
#   'title',
#   'realize',
#   'supporting',
#   'role',
#   'even',
#   'martin',
#   'short',
#   'managed',
#   'distinct',
#   'supporting',
#   'characteri',
#   'understand',
#   'attraction',
#   'imaginary',
#   'world',
#   'created',
#   'good',
#   'romantic',
#   'comedy',
#   'film',
#   'prozac',
#   'version',
#   'imaginary',
#   'world',
#   'im',
#   'frightened',
#   'consider',
#   'anyone',
#   'could',
#   'enjoy',
#   'even',
#   'pure',
#   'fantasy'],
#  ['appalling',
#   'piece',
#   'rubbish',
#   'people',
#   'blubber',
#   'good',
#   'yes',
#   'arty',
#   'yes',
#   'foreign',
#   'thats',
#   'enough',
#   'plot',
#   'boring',
#   'disjointed',
#   'like',
#   'reality',
#   'show',
#   'slickly',
#   'madethe',
#   'people',
#   'intrinsically',
#   'uninteresting',
#   'characters',
#   'dont',
#   'enough',
#   'depth',
#   'feel',
#   'empathy',
#   'based',
#   'real',
#   'people',
#   'feel',
#   'sorry',
#   'themthe',
#   'violence',
#   'violent',
#   'seems',
#   'quite',
#   'ostentatious',
#   'gratuitous',
#   'like',
#   'producer',
#   'visions',
#   'quenton',
#   'tarantino',
#   'think',
#   'much',
#   'eitherand',
#   'oh',
#   'yes',
#   'neighbours',
#   'like',
#   'id',
#   'move'],
#  ['okay',
#   'couple',
#   'hours',
#   'waste',
#   'really',
#   'hate',
#   'life',
#   'would',
#   'say',
#   'watch',
#   'movie',
#   'anything',
#   'good',
#   'laughs',
#   'obese',
#   'topless',
#   'natives',
#   'also',
#   'special',
#   'effects',
#   'bad',
#   'probably',
#   'outlawed',
#   'states',
#   'seriuosly',
#   'rating',
#   'pg',
#   'pretty',
#   'humorous',
#   'see',
#   'native',
#   'porn',
#   'extravaganza',
#   'wouldnt',
#   'give',
#   'movie',
#   'retarded',
#   'nephew',
#   'couldnt',
#   'even',
#   'show',
#   'iraqi',
#   'prisoners',
#   'without',
#   'violating',
#   'geneva',
#   'convention',
#   'plot',
#   'sketchy',
#   'clich',
#   'dumb',
#   'stupid',
#   'acting',
#   'horrible',
#   'ending',
#   'painful',
#   'watch',
#   'actually',
#   'began',
#   'pouring',
#   'salt',
#   'eye',
#   'take',
#   'mind',
#   'idiocy',
#   'filling',
#   'tv',
#   'screen'],
#  ['unfortunately',
#   'many',
#   'consumers',
#   'write',
#   'reviews',
#   'imdb',
#   'equate',
#   'low',
#   'budget',
#   'good',
#   'whatever',
#   'else',
#   'movie',
#   'might',
#   'need',
#   'budget',
#   'really',
#   'isnt',
#   'part',
#   'big',
#   'sets',
#   'lots',
#   'special',
#   'effects',
#   'would',
#   'turned',
#   'another',
#   'lara',
#   'croft',
#   'movie',
#   'step',
#   'two',
#   'better',
#   'thatthe',
#   'nearly',
#   'unknown',
#   'alexandra',
#   'staden',
#   'captivating',
#   'enigmatic',
#   'modesty',
#   'crucial',
#   'movie',
#   'work',
#   'wise',
#   'little',
#   'smiles',
#   'knowing',
#   'looks',
#   'formidable',
#   'find',
#   'wishing',
#   'camera',
#   'wont',
#   'leaver',
#   'face',
#   'makes',
#   'workable',
#   'bad',
#   'guy',
#   'nikolai',
#   'played',
#   'also',
#   'little',
#   'known',
#   'us',
#   'least',
#   'nikolaj',
#   'coasterwaldau',
#   'might',
#   'take',
#   'unusually',
#   'cerebral',
#   'interest',
#   'something',
#   'modesty',
#   'exploit',
#   'able',
#   'divert',
#   'raping',
#   'shove',
#   'spitting',
#   'stop',
#   'wasting',
#   'time',
#   'storming',
#   'heavily',
#   'armed',
#   'yet',
#   'suddenly',
#   'diffident',
#   'henchmen',
#   'making',
#   'scene',
#   'like',
#   'plausible',
#   'doesnt',
#   'happen',
#   'accidentprobably',
#   'biggest',
#   'problem',
#   'railthin',
#   'staden',
#   'playing',
#   'modesty',
#   'isnt',
#   'believable',
#   'go',
#   'hand',
#   'hand',
#   'athletic',
#   'muscled',
#   'looking',
#   'guy',
#   'like',
#   'coasterwaldau',
#   'beat',
#   'aint',
#   'peta',
#   'wilson',
#   'pumpedup',
#   'hilary',
#   'swank',
#   'type',
#   'actress',
#   'throw',
#   'convincing',
#   'punch',
#   'coasterwaldau',
#   'letting',
#   'overpowered',
#   'staden',
#   'looks',
#   'like',
#   'hes',
#   'roughhousing',
#   'little',
#   'sistersince',
#   'really',
#   'action',
#   'film',
#   'isnt',
#   'big',
#   'flaw',
#   'hope',
#   'better',
#   'make',
#   'sequels'],
#  ['got',
#   'one',
#   'worst',
#   'films',
#   'ever',
#   'seen',
#   'cast',
#   'international',
#   'one',
#   'australianpretendingtobebritish',
#   'stage',
#   'american',
#   'character',
#   'english',
#   'name',
#   'sporting',
#   'unrecognizable',
#   'european',
#   'accent',
#   'passable',
#   'efforts',
#   'acting',
#   'motley',
#   'crew',
#   'totally',
#   'undermined',
#   'plot',
#   'script',
#   'especial',
#   'inanity',
#   'short',
#   'shoestrings',
#   'films',
#   'budget',
#   'overall',
#   'production',
#   'values',
#   'low',
#   'would',
#   'trouble',
#   'winning',
#   'cinematic',
#   'limbo',
#   'competition',
#   'last',
#   'twenty',
#   'years',
#   'seen',
#   'horror',
#   'films',
#   'stalkn',
#   'slash',
#   'thrillers',
#   'extraordinary',
#   'though',
#   'necessarily',
#   'high',
#   'quality',
#   'made',
#   'budget',
#   'recent',
#   'examples',
#   'include',
#   'poorly',
#   'made',
#   'totally',
#   'scary',
#   'blair',
#   'witch',
#   'project',
#   'course',
#   'recent',
#   'lowbudget',
#   'winner',
#   'saw',
#   'featuring',
#   'practically',
#   'unknown',
#   'leads',
#   'gary',
#   'elwes',
#   'someone',
#   'dont',
#   'remember',
#   'even',
#   'seen',
#   'darkhunters',
#   'shocking',
#   'find',
#   'known',
#   'character',
#   'actor',
#   'dominique',
#   'pinon',
#   'hollywood',
#   'hasbeen',
#   'jeff',
#   'fahey',
#   'struggling',
#   'valiantly',
#   'save',
#   'film',
#   'embarrassing',
#   'see',
#   'handsome',
#   'leading',
#   'man',
#   'fahey',
#   'corny',
#   'makeup',
#   'uttering',
#   'bizarrely',
#   'bad',
#   'lines',
#   'would',
#   'rated',
#   'film',
#   'possible'],
#  ['luscious',
#   'candace',
#   'bergen',
#   'prim',
#   'victorian',
#   'beauty',
#   'kidnapped',
#   'sean',
#   'connery',
#   'devilish',
#   'desert',
#   'sheikh',
#   'go',
#   'wrong',
#   'oh',
#   'let',
#   'count',
#   'ways',
#   'earthy',
#   'primitive',
#   'sean',
#   'connery',
#   'exactly',
#   'right',
#   'man',
#   'tame',
#   'brittle',
#   'classy',
#   'beauty',
#   'like',
#   'candace',
#   'well',
#   'underwhelming',
#   'role',
#   'thats',
#   'instead',
#   'dialog',
#   'real',
#   'issues',
#   'woman',
#   'man',
#   'babble',
#   'nonsense',
#   'allah',
#   'wind',
#   'blows',
#   'destiny',
#   'across',
#   'desert',
#   'sands',
#   'john',
#   'milius',
#   'director',
#   'known',
#   'worship',
#   'naked',
#   'male',
#   'bodies',
#   'brute',
#   'military',
#   'force',
#   'insight',
#   'interest',
#   'conventional',
#   'human',
#   'relationships',
#   'maddening',
#   'way',
#   'cutting',
#   'away',
#   'desert',
#   'lovers',
#   'every',
#   'time',
#   'looks',
#   'like',
#   'candace',
#   'might',
#   'get',
#   'kissed',
#   'instead',
#   'watching',
#   'nature',
#   'take',
#   'course',
#   'two',
#   'fabulously',
#   'attractive',
#   'people',
#   'picturesque',
#   'landscape',
#   'treated',
#   'endless',
#   'mean',
#   'endless',
#   'shots',
#   'brian',
#   'keith',
#   'flashing',
#   'walrus',
#   'sized',
#   'choppers',
#   'delivering',
#   'gritty',
#   'sermons',
#   'joys',
#   'teddy',
# ...
#   'gets',
#   'ideas',
#   'fun',
#   'quickly',
#   'reminded',
#   'married',
#   'need',
#   'start',
#   'acting',
#   'like',
#   'emotion',
#   'two',
#   'characters',
#   'raw',
#   'expressive',
#   'plot',
#   'continues',
#   'especially',
#   'note',
#   'giving',
#   'storyline',
#   'away',
#   'split',
#   'sissy',
#   'falls',
#   'ex',
#   'con',
#   'penchant',
#   'abuse',
#   'cruelty',
#   'soon',
#   'realizes',
#   'grass',
#   'always',
#   'greener',
#   'sidehow',
#   'anyone',
#   'compare',
#   'bud',
#   'vinnie',
#   'barbirino',
#   'shocking',
#   'john',
#   'travolta',
#   'gave',
#   'exceptional',
#   'performance',
#   'worthy',
#   'recognition',
#   'believable',
#   'real',
#   'scene',
#   'shaves',
#   'beard',
#   'first',
#   'see',
#   'barstill',
#   'gives',
#   'goosebumps',
#   'mind',
#   'huge',
#   'travolta',
#   'fan',
#   'come',
#   'see',
#   'sissy',
#   'kicking',
#   'boots',
#   'early',
#   'film',
#   'deb',
#   'winger',
#   'real',
#   'found',
#   'sympathizing',
#   'pens',
#   'note',
#   'emotions',
#   'bud',
#   'sneaking',
#   'clean',
#   'house',
#   'break',
#   'supporting',
#   'cast',
#   'incredible',
#   'wes',
#   'played',
#   'scott',
#   'glenn',
#   'gave',
#   'first',
#   'rate',
#   'performance',
#   'made',
#   'hate',
#   'curse',
#   'abused',
#   'sissy',
#   'madolyn',
#   'smithosborne',
#   'buds',
#   'mistressgirlfriend',
#   'authentic',
#   'large',
#   'chested',
#   'girls',
#   'across',
#   'us',
#   'prayed',
#   'wake',
#   'flat',
#   'chested',
#   'wear',
#   'clothes',
#   'donned',
#   'film',
#   'biggest',
#   'kudoss',
#   'go',
#   'barry',
#   'corbin',
#   'brooke',
#   'anderson',
#   'buds',
#   'aunt',
#   'uncle',
#   'seemed',
#   'like',
#   'someones',
#   'aunt',
#   'uncle',
#   'somewhere',
#   'texas',
#   'however',
#   'small',
#   'role',
#   'made',
#   'film',
#   'much',
#   'bigger',
#   'lifelike',
#   'two',
#   'memorable',
#   'scenes',
#   'dolly',
#   'parton',
#   'contest',
#   'unforgettable',
#   'scene',
#   'bud',
#   'aunt',
#   'stand',
#   'outside',
#   'one',
#   'characters',
#   'death',
#   'dialog',
#   'touchingif',
#   'watch',
#   'true',
#   'american',
#   'love',
#   'story',
#   'recommend',
#   'take',
#   'isa',
#   'film',
#   'time',
#   'gave',
#   'us',
#   'voyeurism',
#   'world',
#   'unlike',
#   'real',
#   'enough',
#   'enjoyment',
#   'entertainment',
#   'world',
#   'sounds',
#   'similar',
#   'enjoy',
#   'much',
#   'lastly',
#   'music',
#   'however',
#   'dated',
#   'sure',
#   'send',
#   'back',
#   'time',
#   'years',
#   'age'],
#  ['abderrahmane',
#   'sissako',
#   'may',
#   'known',
#   'made',
#   'bamako',
#   'rest',
#   'us',
#   'sit',
#   'back',
#   'mystification',
#   'confusion',
#   'trying',
#   'figure',
#   'purpose',
#   'might',
#   'beenthe',
#   'nominal',
#   'plot',
#   'involves',
#   'young',
#   'african',
#   'singer',
#   'whos',
#   'planning',
#   'leaving',
#   'unemployed',
#   'husband',
#   'find',
#   'work',
#   'city',
#   'far',
#   'screen',
#   'time',
#   'taken',
#   'publicists',
#   'film',
#   'describe',
#   'mock',
#   'trial',
#   'key',
#   'financial',
#   'institutions',
#   'dealing',
#   'overwhelming',
#   'economic',
#   'hardships',
#   'africa',
#   'thats',
#   'well',
#   'good',
#   'suppose',
#   'arguments',
#   'ideas',
#   'put',
#   'forth',
#   'undramatic',
#   'pedantic',
#   'way',
#   'lose',
#   'force',
#   'impact',
#   'put',
#   'another',
#   'way',
#   'director',
#   'found',
#   'means',
#   'actually',
#   'incorporate',
#   'issues',
#   'injurious',
#   'effect',
#   'colonialism',
#   'african',
#   'people',
#   'problem',
#   'african',
#   'debt',
#   'anything',
#   'even',
#   'remotely',
#   'resembling',
#   'compelling',
#   'storyline',
#   'film',
#   'might',
#   'achieved',
#   'intellectual',
#   'emotional',
#   'resonance',
#   'clearly',
#   'lacksthe',
#   'topics',
#   'movie',
#   'dealing',
#   'may',
#   'relevant',
#   'important',
#   'trying',
#   'pass',
#   'amounts',
#   'two',
#   'hours',
#   'worth',
#   'speechifying',
#   'actual',
#   'honesttogod',
#   'movie',
#   'likely',
#   'garner',
#   'much',
#   'audience',
#   'ones',
#   'message'],
#  ['pinjar',
#   'truly',
#   'masterpiece',
#   'thought',
#   'provoking',
#   'film',
#   'makes',
#   'think',
#   'makes',
#   'question',
#   'culture',
#   'without',
#   'doubt',
#   'best',
#   'hindi',
#   'movie',
#   'seen',
#   'date',
#   'film',
#   'shown',
#   'movie',
#   'festivals',
#   'around',
#   'world',
#   'believe',
#   'would',
#   'serious',
#   'contender',
#   'cannes',
#   'characters',
#   'perfectly',
#   'cast',
#   'urmila',
#   'matkondar',
#   'manoj',
#   'bhajpai',
#   'haunting',
#   'rolesthe',
#   'story',
#   'movie',
#   'tells',
#   'partition',
#   'important',
#   'story',
#   'one',
#   'never',
#   'forgottenit',
#   'biases',
#   'prejudices',
#   'given',
#   'partition',
#   'human',
#   'story',
#   'one',
#   'country',
#   'depicted',
#   'good',
#   'bad',
#   'evil',
#   'indians',
#   'evil',
#   'pakistanis',
#   'good',
#   'indians',
#   'pakistanis',
#   'cinematography',
#   'excellent',
#   'music',
#   'melodious',
#   'meaningful',
#   'haunting',
#   'everything',
#   'movie',
#   'amazingand',
#   'acting',
#   'took',
#   'breath',
#   'away',
#   'perfectly',
#   'cast'],
#  ['liked',
#   'movie',
#   'many',
#   'people',
#   'refer',
#   'sabrina',
#   'teenage',
#   'feminist',
#   'lot',
#   'movies',
#   'melissa',
#   'joan',
#   'hart',
#   'still',
#   'really',
#   'surprised',
#   'movie',
#   'great',
#   'part',
#   'mary',
#   'fights',
#   'justice',
#   'roommate',
#   'raped',
#   'could',
#   'tell',
#   'hart',
#   'extremely',
#   'determined',
#   'movie',
#   'showed',
#   'also',
#   'liked',
#   'lisa',
#   'dean',
#   'ryan',
#   'marys',
#   'roommate',
#   'effective',
#   'making',
#   'feel',
#   'sorry',
#   'character',
#   'raped',
#   'josh',
#   'hopkins',
#   'good',
#   'cocky',
#   'egotistical',
#   'rapist',
#   'lochlyn',
#   'munro',
#   'convincingly',
#   'played',
#   'character',
#   'acting',
#   'movie',
#   'better',
#   'tv',
#   'movies',
#   'opinionthe',
#   'movie',
#   'pretty',
#   'predictable',
#   'though',
#   'also',
#   'expected',
#   'ending',
#   'abrupt',
#   'delivery',
#   'could',
#   'better',
#   'performances',
#   'overall',
#   'plot',
#   'make',
#   'problems'],
#  ['film',
#   'first',
#   'indicated',
#   'great',
#   'actor',
#   'martin',
#   'sheen',
#   'really',
#   'modestly',
#   'claims',
#   'charlie',
#   'better',
#   'actor',
#   'charlie',
#   'cant',
#   'hold',
#   'candle',
#   'himi',
#   'found',
#   'suspenseful',
#   'thoroughly',
#   'enjoyed',
#   'intertwining',
#   'love',
#   'story',
#   'main',
#   'plot',
#   'usually',
#   'hate',
#   'love',
#   'stories',
#   'theres',
#   'great',
#   'plot',
#   'twist',
#   'end',
#   'struck',
#   'fully',
#   'credible',
#   'particularly',
#   'early',
#   'time',
#   'period',
#   'probably',
#   'alsothe',
#   'final',
#   'scene',
#   'edge',
#   'seat',
#   'film',
#   'roundly',
#   'illustrates',
#   'treachery',
#   'often',
#   'doled',
#   'trust',
#   'declared',
#   'enemies',
#   'common',
#   'suspect',
#   'finally',
#   'human',
#   'compassion',
#   'found',
#   'least',
#   'expect',
#   'itirenerose'],
#  ['know',
#   'voted',
#   'really',
#   'deserves',
#   'half',
#   'star',
#   'hated',
#   'stupid',
#   'unrealistic',
#   'cant',
#   'believe',
#   'stars',
#   'signed',
#   'make',
#   'ridiculously',
#   'absurd',
#   'projectjames',
#   'g',
#   'cathrine',
#   'ohara',
#   'excellent',
#   'characters',
#   'ben',
#   'affleck',
#   'christina',
#   'applegate',
#   'good',
#   'story',
#   'sucked',
#   'encourage',
#   'anyone',
#   'sees',
#   'video',
#   'store',
#   'even',
#   'bother',
#   'picking',
#   'reading',
#   'back',
#   'cover',
#   'walk',
#   'awayi',
#   'dont',
#   'even',
#   'want',
#   'get',
#   'movie',
#   'stupid',
#   'pontificate',
#   'aboutdont',
#   'rent',
#   'horrible',
#   'horrible'],
#  ['could',
#   'get',
#   'ed',
#   'asner',
#   'didnt',
#   'get',
#   'actors',
#   'instead',
#   'people',
#   'go',
#   'church',
#   'producers',
#   'protagonist',
#   'throw',
#   'wise',
#   'old',
#   'sage',
#   'character',
#   'ground',
#   'never',
#   'danger',
#   'forced',
#   'old',
#   'guy',
#   'mask',
#   'injury',
#   'pride',
#   'young',
#   'guy',
#   'would',
#   'feel',
#   'guilty',
#   'leaving',
#   'life',
#   'long',
#   'disability',
#   'guess',
#   'thats',
#   'main',
#   'character',
#   'refuses',
#   'money',
#   'though',
#   'old',
#   'guy',
#   'works',
#   'like',
#   'dog',
#   'even',
#   'volunteers',
#   'extra',
#   'work',
#   'dbag',
#   'boyfriend',
#   'bad',
#   'guy',
#   'longdistance',
#   'boyfriend',
#   'soldier',
#   'better',
#   'good',
#   'reason',
#   'jealous',
#   'good',
#   'reason',
#   'get',
#   'away',
#   'hometown',
#   'protective',
#   'controlling',
#   'manipulative',
#   'father',
#   'characters',
#   'meant',
#   'likable',
#   'arent',
#   'everyone',
#   'else',
#   'bad',
#   'boyfriend',
#   'meet',
#   'anyway',
#   'wine',
#   'broker',
#   'saw',
#   'mill',
#   'worker'],
#  ['im',
#   'picky',
#   'horror',
#   'movies',
#   'im',
#   'willing',
#   'watch',
#   'pretty',
#   'much',
#   'doesnt',
#   'mean',
#   'im',
#   'willing',
#   'rewatch',
#   'many',
#   'wont',
#   'criticism',
#   'movie',
#   'creepy',
#   'well',
#   'done',
#   'fact',
#   'think',
#   'movie',
#   'would',
#   'make',
#   'excellent',
#   'doublebill',
#   'session',
#   'specify',
#   'get',
#   'comments',
#   'watched',
#   'alone',
#   'started',
#   'watching',
#   'going',
#   'bed',
#   'got',
#   'minutes',
#   'realized',
#   'effective',
#   'saved',
#   'rest',
#   'morning',
#   'even',
#   'watching',
#   'broad',
#   'daylight',
#   'still',
#   'creepy',
#   'however',
#   'cant',
#   'vouch',
#   'effective',
#   'would',
#   'watching',
#   'larger',
#   'groupafter',
#   'death',
#   'daughter',
#   'couple',
#   'move',
#   'remote',
#   'cabin',
#   'means',
#   'trying',
#   'come',
#   'terms',
#   'death',
#   'let',
#   'make',
#   'note',
#   'death',
#   'one',
#   'rare',
#   'movies',
#   'doesnt',
#   'shy',
#   'away',
#   'death',
#   'child',
#   'much',
#   'important',
#   'sets',
#   'tone',
#   'well',
#   'explains',
#   'much',
#   'acting',
#   'permeates',
#   'moviethe',
#   'couple',
#   'well',
#   'wife',
#   'distanced',
#   'relationship',
#   'husband',
#   'try',
#   'bring',
#   'back',
#   'comments',
#   'complained',
#   'acting',
#   'one',
#   'specified',
#   'act',
#   'like',
#   'father',
#   'daughter',
#   'husband',
#   'wife',
#   'thats',
#   'legitimate',
#   'hes',
#   'trying',
#   'give',
#   'direction',
#   'role',
#   'men',
#   'sometimes',
#   'take',
#   'onthere',
#   'variety',
#   'scares',
#   'film',
#   'fairly',
#   'nonviolent',
#   'though',
#   'grotesque',
#   'ways',
#   'story',
#   'feels',
#   'straightforward',
#   'film',
#   'takes',
#   'odd',
#   'turn',
#   'near',
#   'end',
#   'turn',
#   'absurd',
#   'certainly',
#   'expected',
#   'way',
#   'things',
#   'progressingmoody',
#   'atmospheric',
#   'well',
#   'done',
#   'something',
#   'appears',
#   'shot',
#   'video'],
#  ['would',
#   'give',
#   'movie',
#   'rather',
#   'would',
#   'least',
#   'time',
#   'ive',
#   'seen',
#   'first',
#   'time',
#   'could',
#   'wait',
#   'work',
#   'based',
#   'artistic',
#   'abilities',
#   'directors',
#   'idealistic',
#   'would',
#   'rather',
#   'say',
#   'idiotic',
#   'habits',
#   'kazakhstan',
#   'government',
#   'shame',
#   'qazaqfilm',
#   'shooting',
#   'nice',
#   'movies',
#   'honoured',
#   'name',
#   'shaken',
#   'aimanov',
#   'actually',
#   'ran',
#   'movies',
#   'like',
#   'konec',
#   'atamana',
#   'kyz',
#   'zhibek',
#   'even',
#   'aldar',
#   'kose',
#   'mr',
#   'aimanovs',
#   'death',
#   'production',
#   'quality',
#   'movies',
#   'went',
#   'almost',
#   'dramatically',
#   'years',
#   'time',
#   'films',
#   'produced',
#   'however',
#   'late',
#   'assa',
#   'shot',
#   'film',
#   'first',
#   'organised',
#   'crime',
#   'groups',
#   'big',
#   'country',
#   'one',
#   'year',
#   'later',
#   'mr',
#   'rashid',
#   'nugmanov',
#   'shot',
#   'another',
#   'film',
#   'costaring',
#   'actorsinger',
#   'vtsoy',
#   'time',
#   'already',
#   'sovietrussian',
#   'rock',
#   'legend',
#   'movie',
#   'called',
#   'igla',
#   'needle',
#   'something',
#   'completely',
#   'new',
#   'somebody',
#   'called',
#   'period',
#   'resurrection',
#   'new',
#   'kazakh',
#   'movie',
#   'wave',
#   'unfortunately',
#   'nowadays',
#   'quality',
#   'movies',
#   'directors',
#   'shooting',
#   'movies',
#   'french',
#   'japanese',
#   'financial',
#   'support',
#   'thus',
#   'movies',
#   'public',
#   'authors',
#   'professional',
#   'critics',
#   'take',
#   'price',
#   'international',
#   'author',
#   'movie',
#   'festivals',
#   'become',
#   'business',
#   'asset',
#   'products',
#   'back',
#   'nomads',
#   'movies',
#   'usually',
#   'unpopular',
#   'vast',
#   'aspects',
#   'effects',
#   'nikita',
#   'mikhalkovs',
#   'sibirski',
#   'cyrilnik',
#   'russian',
#   'tsars',
#   'also',
#   'shot',
#   'parities',
#   'foreign',
#   'partners',
#   'think',
#   'french',
#   'maybe',
#   'british',
#   'nobdy',
#   'liked',
#   'even',
#   'russian',
#   'public',
#   'become',
#   'main',
#   'topic',
#   'comedians',
#   'comedy',
#   'shows',
#   'like',
#   'kvn',
#   'imho'],
#  ['year',
#   'keep',
#   'mind',
#   'two',
#   'years',
#   'ago',
#   'four',
#   'two',
#   'men',
#   'motivation',
#   'create',
#   'miraculous',
#   'piece',
#   'art',
#   'side',
#   'mississippithanks',
#   'jere',
#   'cunningham',
#   'tom',
#   'flynn',
#   'world',
#   'enjoy',
#   'second',
#   'string',
#   'delicious',
#   'tv',
#   'movie',
#   'depicting',
#   'tale',
#   'ragtag',
#   'gang',
#   'second',
#   'stringers',
#   'thus',
#   'title',
#   'thrust',
#   'position',
#   'starters',
#   'due',
#   'order',
#   'bad',
#   'oystersbecause',
#   'motivational',
#   'direction',
#   'director',
#   'robert',
#   'lieberman',
#   'buffalo',
#   'bills',
#   'last',
#   'minute',
#   'qb',
#   'dan',
#   'give',
#   'em',
#   'hell',
#   'heller',
#   'portrayed',
#   'canadian',
#   'actor',
#   'gil',
#   'bellows',
#   'oft',
#   'super',
#   'bowl',
#   'snakebitten',
#   'bills',
#   'find',
#   'ultimate',
#   'positionwith',
#   'intriguing',
#   'mix',
#   'internal',
#   'external',
#   'conflict',
#   'love',
#   'story',
#   'comraderie',
#   'fine',
#   'sport',
#   'football',
#   'bring',
#   'overall',
#   'theory',
#   'underdog',
#   'compete',
#   'second',
#   'string',
#   'excellent',
#   'movie',
#   'worthy',
#   'viewing',
#   'every',
#   'possible',
#   'moment',
#   'appears',
#   'tntthe',
#   'thing',
#   'potentially',
#   'bad',
#   'production',
#   'spelling',
#   'costume',
#   'designers',
#   'first',
#   'name',
#   'jenifur',
#   'jarvis'],
#  ['one',
#   'wants',
#   'character',
#   'movie',
#   'disturbing',
#   'sexual',
#   'encounter',
#   'would',
#   'shame',
#   'character',
#   'later',
#   'life',
#   'thing',
#   'left',
#   'audience',
#   'would',
#   'see',
#   'shameful',
#   'bestiality',
#   'done',
#   'judging',
#   'comments',
#   'even',
#   'succeed',
#   'well',
#   'remember',
#   'one',
#   'funny',
#   'scene',
#   'though',
#   'admit',
#   'turn',
#   'finished',
#   'watch',
#   'part',
#   'directors',
#   'commentary',
#   'appears',
#   'surprised',
#   'anyone',
#   'movie',
#   'well',
#   'want',
#   'get',
#   'feeling',
#   'get',
#   'movie',
#   'cheaper',
#   'stick',
#   'head',
#   'pile',
#   'manure',
#   'breath',
#   'deeply'],
#  ['saw',
#   'movie',
#   'tvive',
#   'lost',
#   'dad',
#   'young',
#   'movie',
#   'surely',
#   'touch',
#   'mei',
#   'feel',
#   'lost',
#   'little',
#   'girl',
#   'desi',
#   'feltthe',
#   'feeling',
#   'wanting',
#   'see',
#   'father',
#   'againwanting',
#   'talk',
#   'himor',
#   'least',
#   'given',
#   'chance',
#   'say',
#   'goodbyeand',
#   'im',
#   'touched',
#   'letter',
#   'wrote',
#   'back',
#   'hersaying',
#   'father',
#   'read',
#   'letter',
#   'sent',
#   'back',
#   'someone',
#   'reply',
#   'buy',
#   'present',
#   'isnt',
#   'shop',
#   'heavenit',
#   'lets',
#   'feel',
#   'miracles',
#   'exist'],
#  ['picture',
#   'someone',
#   'makes',
#   'film',
#   'columbine',
#   'virginia',
#   'tech',
#   'massacre',
#   'film',
#   'directed',
#   'guy',
#   'home',
#   'alone',
#   'know',
#   'isnt',
#   'bare',
#   'stars',
#   'sean',
#   'astin',
#   'goonies',
#   'picture',
#   'terrorists',
#   'overpowered',
#   'buckets',
#   'water',
#   'top',
#   'ajar',
#   'doors',
#   'marbles',
#   'need',
#   'see',
#   'film',
#   'unfortunately',
#   'doesnt',
#   'go',
#   'way',
#   'actually',
#   'skateboard',
#   'lying',
#   'floor',
#   'evil',
#   'mexicans',
#   'trip',
#   'halfway',
#   'give',
#   'didnt',
#   'go',
#   'crazy',
#   'enough',
#   'pity',
#   'seemed',
#   'like',
#   'would',
#   'comical',
#   'cheesiness',
#   'well',
#   'worth',
#   'cult',
#   'status'],
#  ['expected',
#   'movie',
#   'originally',
#   'supposed',
#   'show',
#   'election',
#   'cbss',
#   'last',
#   'shot',
#   'throwing',
#   'dig',
#   'bush',
#   'movie',
#   'awful',
#   'yet',
#   'im',
#   'still',
#   'watching',
#   'minor',
#   'spoiler',
#   'think',
#   'cbs',
#   'got',
#   'people',
#   'provided',
#   'memos',
#   'semi',
#   'cut',
#   'half',
#   'sequence',
#   'bad',
#   'boyfriend',
#   'storyline',
#   'acting',
#   'contrived',
#   'dialog',
#   'like',
#   'ed',
#   'wood',
#   'movie',
#   'ever',
#   'came',
#   'script',
#   'please',
#   'us',
#   'favor',
#   'stop',
#   'writing',
#   'want',
#   'see',
#   'decent',
#   'b',
#   'grade',
#   'disaster',
#   'movies',
#   'see',
#   'earthquake',
#   'flood',
#   'etc',
#   'avoid',
#   'mess',
#   'movie',
#   'hint',
#   'cbs',
#   'avoid',
#   'showing',
#   'us',
#   'crap',
#   'give',
#   'us',
#   'reruns',
#   'csi',
#   'instead',
#   'better',
#   'acting',
#   'believable'],
#  ...]

# %%
from gensim.models import Word2Vec


w2v_model = Word2Vec(tokenized_corpus, vector_size=100, window=5, min_count=5, workers=4, epochs=1000)

# %%
w2v_model.wv.get_vector('good')
# Out:
# array([-1.2162328e+00,  2.8214784e+00, -1.6183339e+00, -6.6693825e-01,
#         3.1950185e+00, -2.5314000e-01, -1.1005534e+00,  2.3824410e+00,
#         2.1774043e-01, -9.0693676e-01, -1.3202015e+00, -3.0586648e+00,
#        -1.6025095e+00, -4.2471405e-02,  1.1779610e+00, -2.2992020e+00,
#         1.6685644e+00, -1.5037817e+00,  3.1916767e-01, -4.8470378e+00,
#        -1.1382118e+00,  1.4438250e+00,  1.3072069e+00,  1.6388686e+00,
#         5.8727002e-01,  7.9172087e-01,  8.9846438e-01,  1.4334803e+00,
#        -3.8484967e+00,  6.4467245e-01,  5.3743535e-01,  3.1226642e+00,
#        -1.0429981e+00, -2.4385281e+00,  8.3032900e-01,  7.8326362e-01,
#         7.4336153e-01, -8.4292746e-01, -4.3271947e-01, -1.9767152e+00,
#        -1.6679970e+00, -1.3975409e-01, -1.6176885e-01,  3.8531470e-01,
#         2.1063437e+00, -2.9386628e+00, -1.9809042e+00,  5.2611160e-01,
#         6.8800747e-01,  4.0107608e+00,  7.9448837e-05, -2.0757146e+00,
#         1.2549385e+00, -9.0661758e-01, -1.4107471e+00, -2.2575657e-01,
#        -2.5523520e+00, -2.7376797e+00, -1.7825023e+00,  6.8059993e-01,
#         1.0625089e+00,  1.7340642e-01, -9.4321525e-01,  8.2015675e-01,
#         3.8093042e-02, -5.7833546e-01,  2.3751328e+00,  2.1612582e+00,
#        -2.2188952e+00,  3.0994756e+00,  6.6691327e-01,  3.1928604e+00,
#         9.5205146e-01, -2.2889376e+00,  9.0765810e-01,  1.6988169e+00,
#         1.0716957e+00, -1.3821899e+00, -2.7532310e+00, -4.9982646e-01,
#        -1.0343047e+00, -9.1705245e-01, -3.8156703e-01, -8.9557248e-01,
#        -1.5893426e+00,  1.1511770e+00, -1.3500257e+00,  7.0680952e-01,
#        -1.4902104e+00, -1.1251738e+00,  4.7104087e+00, -1.4333225e+00,
#         2.4232125e+00, -1.0076053e+00,  1.4831688e+00, -8.4693742e-01,
#         2.3722842e+00, -1.6744724e-01,  5.8601511e-01,  1.6981679e+00],
#       dtype=float32)

# %%
train_vectors = features_embeddings_trained(train_tokenized_corpus)
print(len(train_vectors))
train_vectors[0].shape
# Out:
# 2010
# (100,)

# %%
test_vectors = features_embeddings_trained(test_tokenized_corpus)
print(len(test_vectors))
test_vectors[0].shape
# Out:
# 990
# (100,)

# %%
pd.DataFrame(train_vectors)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.542037  0.207305  1.294649  0.187143  0.488779  0.268629 -0.910947
# 1    -0.547686  0.355771  0.166179 -0.678580  0.351975 -0.926832 -0.048489
# 2     0.116587 -0.036734  0.051043  0.324732  0.158343 -0.727407  0.036239
# 3    -0.228311  0.485657  0.002040 -1.189860  0.235160  0.173281  0.261406
# 4    -0.905322  0.684515  0.226590 -0.571770  1.019778 -0.274504  0.277069
# ...        ...       ...       ...       ...       ...       ...       ...
# 2005  0.416515  1.469960 -0.865980 -0.318793  0.090127 -0.181142 -0.393172
# 2006 -0.801499  0.963594  1.378747  0.715873 -0.079275 -0.527411 -0.051364
# 2007 -0.084227  0.398447  0.062124 -0.537270  0.218859  0.075756 -0.187547
# 2008 -0.035457  0.467487  0.638060 -0.615420 -0.076184 -0.966929 -0.580523
# 2009 -0.474222  0.218642  0.875947 -1.075327  1.048074 -0.261274  0.521157
#
#             7         8         9   ...        90        91        92  \
# 0     0.615916  0.199186  1.611569  ... -0.178649 -0.064968  0.608629
# 1     0.668812 -0.215949  0.300916  ...  0.782023 -0.358429  0.202502
# 2     0.835853  0.013212 -0.186487  ...  0.489580  0.111286 -0.297007
# 3     1.065048 -0.415442  0.322661  ...  0.660357  0.203004  1.263204
# 4     0.826453 -0.102960 -0.080917  ...  0.302292 -0.411636  0.831800
# ...        ...       ...       ...  ...       ...       ...       ...
# 2005  1.767932 -0.033844  0.087816  ...  0.204167 -0.771697 -0.384556
# 2006  1.312657 -0.351139 -0.641406  ...  0.463297 -0.044615  0.106691
# 2007 -0.189401 -0.381424  0.118413  ...  0.019469  0.049975  0.154613
# 2008  0.349052  0.073621  0.165564  ...  0.978257 -1.152258  0.020195
# 2009 -0.936941 -0.114306 -0.966114  ...  0.222775  0.602532  0.009938
#
#             93        94        95        96        97        98        99
# 0     0.062858  0.090038  1.146683  0.547711  0.386943 -0.177861  0.488217
# 1    -0.425116  0.637140  0.518589  0.706520 -0.911478  0.039270  0.930268
# 2     0.147138  0.424103  0.587565  0.367007 -0.434915  0.163814  0.683255
# 3     0.071106  1.013812  0.558073  0.958466 -1.139623  1.354658  0.349583
# 4     0.003049  1.002412  0.173870  0.225041  0.049867  0.011661 -0.309264
# ...        ...       ...       ...       ...       ...       ...       ...
# 2005  0.934168 -0.252340  0.406547  0.643272 -0.235321 -0.125435 -0.524991
# 2006 -0.112504  0.669756  0.821823  1.140819  0.016741  0.731739  0.154779
# 2007  0.189762 -0.318999  0.190289 -0.010788  0.303954 -0.456986  0.004394
# 2008  0.117045  0.458258 -0.055478 -0.830837  0.583896  0.226798  0.588833
# 2009 -0.006009  1.808176 -0.448657  0.224174  0.818366  0.100349  1.167305
#
# [2010 rows x 100 columns]

# %%
model = LogisticRegression()

# %%
model.fit(train_vectors, train_y)
# Out:
# LogisticRegression()

# %%
train_pred = model.predict(train_vectors)
test_pred = model.predict(test_vectors)

# %%
confusion_matrix(train_y, train_pred)
# Out:
# array([[877, 155],
#        [161, 817]])

# %%
confusion_matrix(test_y, test_pred)
# Out:
# array([[397,  97],
#        [106, 390]])

# %%
print("Train Accuracy : ",accuracy_score(train_y, train_pred))
print("Test Accuracy : ",accuracy_score(test_y, test_pred))
# Out:
# Train Accuracy :  0.8427860696517413
# Test Accuracy :  0.794949494949495

# %% [markdown]
# # Fasttext Taining Model

# %%
from gensim.models.fasttext import FastText

# %%
# Creating a feature vector by averaging all embeddings for all sentences
def features_embeddings_trained(list_of_lists):
    
    # feature vector column length 
    DIMENSION = w2v_model.vector_size
    
    # Zero vector if words not in our w2v_model vocubulary
    zero_vector = np.zeros(DIMENSION)
    
    features = []
    
    # feature vector for each sentence in list_of_lists one by one
    for tokens in list_of_lists:
        
        # feature vector for a single sentence
        feature =  np.zeros(DIMENSION) # shape = 1X DIMENSION
        
        # count for each token/word in a tokens or sentence
        feature_counts = 0 + 1e-5   # to avoid divide-by-zero 
        for token in tokens:
            if token in w2v_model.wv.index_to_key:
                feature += w2v_model.wv[token] # Here both feature and w2v_model[token] are of same shape : 1X DIMENSION
                feature_counts +=1    # Count increases for each token in a tokens
         
        # Average the feature values for each tokens
        if(feature_counts !=0 ):        # for non empty tokens
            features.append(feature/feature_counts) 
        else:                           # for empty tokens
            features.append(zero_vector)
            
    return features

# %%
tokenized_corpus = train_tokenized_corpus + test_tokenized_corpus

# %%
w2v_model = FastText(tokenized_corpus, vector_size=300, window=5, min_count=1, workers=4, epochs=100)

# %%
w2v_model.wv.get_vector('good')
# Out:
# array([-0.39554578,  0.30556968, -0.3278093 ,  0.6070886 , -1.1435615 ,
#         0.6960136 ,  1.8225309 , -0.08764059,  0.02879203,  1.8186275 ,
#        -2.6683233 , -1.1544572 , -3.6363158 ,  1.4927639 ,  0.25606278,
#         1.6747531 , -0.02730703, -0.19937731,  0.5704363 ,  0.37684003,
#        -1.1360894 ,  0.10065033,  0.06069138, -1.2784314 ,  0.1724576 ,
#        -1.0831739 , -1.2671391 ,  0.96431136,  2.237326  ,  0.36201993,
#         0.33683383, -0.8974773 , -2.0102575 , -1.2174679 ,  0.2255754 ,
#         0.07015803,  3.3393335 , -1.8132381 ,  1.234856  ,  2.253016  ,
#        -0.3265842 ,  1.464262  , -0.5921297 , -3.4554558 ,  2.0791218 ,
#         0.12724856, -0.79863393, -2.32285   , -0.89043736,  0.01599858,
#        -0.14147553,  0.27829286, -0.19791688,  0.8342646 ,  0.5525431 ,
#         0.09347764,  0.06730296,  0.73783684,  0.7105636 ,  1.0975491 ,
#         1.3238546 ,  0.13173565,  2.3809848 ,  1.056398  ,  2.9809813 ,
#        -3.7532227 ,  5.270201  ,  1.7451004 , -1.5945438 , -0.32305148,
#        -0.9502613 ,  0.70547146,  0.17194392,  0.9458262 , -2.900502  ,
#         0.2586229 , -0.7458614 , -0.18420224, -0.15836167, -1.7134427 ,
#         1.5093843 , -0.34040973, -0.34182248,  0.01363967,  1.0840988 ,
#        -1.2060056 , -0.8141607 ,  0.80107385, -0.30391312, -1.7194706 ,
#         0.7924281 , -0.3156037 , -1.6107497 ,  0.82973593, -0.38066527,
#        -2.2999804 ,  1.2385507 ,  1.625223  ,  0.4050909 ,  1.7459812 ,
#         1.9668541 ,  0.00616792, -0.45072678,  3.0137138 ,  1.0240337 ,
#        -0.7567594 , -1.9164311 ,  0.5795496 , -1.326035  , -1.402712  ,
#         1.5607452 ,  1.2160598 ,  2.2797527 ,  1.0491899 , -1.590057  ,
#        -1.8134625 , -0.8650263 , -1.5400637 , -0.0501344 , -0.23865324,
#        -1.154392  , -0.24503027,  1.125552  , -0.15003738,  1.956457  ,
#         0.9990286 ,  2.4024084 ,  0.66292536, -2.2376692 , -1.909874  ,
#         2.0926645 ,  0.14323808,  0.1358206 , -1.8737838 ,  2.3714957 ,
#        -1.2321937 , -1.653894  , -3.0600576 , -1.8837434 , -0.18400374,
#        -0.9353066 , -2.7796907 , -2.6179388 ,  1.2566056 , -2.8756783 ,
#         0.13461745, -1.7317624 ,  1.0371697 , -0.02270824,  2.1573641 ,
#        -1.8665242 , -1.642563  , -0.52352387, -1.8570422 , -1.2111748 ,
#        -0.82166743,  1.4018594 ,  1.6572933 ,  0.86284506, -1.82907   ,
#         1.2975348 ,  3.5835845 ,  2.432748  , -0.16322578,  1.2997528 ,
#         1.4835883 ,  1.6059147 ,  2.6282842 , -1.0197964 , -1.4962274 ,
#         1.4273608 , -0.7009372 , -0.13778034, -2.2802107 ,  1.5699024 ,
#        -0.5583206 , -0.12222511,  1.7505306 ,  1.516835  ,  2.05357   ,
#         1.466422  ,  0.97252935, -2.0198991 , -0.05961495,  1.6880143 ,
#         2.3403208 ,  0.23209877,  2.0574481 , -1.3894801 , -1.3842267 ,
#         1.8313485 ,  1.1853551 ,  2.6809886 , -3.8717756 ,  0.5129273 ,
#        -0.57128084,  1.720187  , -1.8293316 ,  1.1407893 , -0.25478193,
#        -0.45075032, -2.056361  ,  1.4831252 , -0.3065128 ,  2.2361152 ,
#        -2.9076066 , -0.03039332,  0.36469582, -0.7054319 , -3.2668312 ,
#        -0.661721  , -1.4950627 ,  0.5750941 , -1.5380181 ,  0.15207295,
#        -1.2430923 ,  0.78197724,  1.1732771 ,  1.0474387 , -2.6344683 ,
#        -0.12747075,  1.0050536 , -2.2132647 ,  1.4931103 ,  2.684985  ,
#        -0.53397334,  0.81202227,  1.4749439 , -1.6287094 ,  2.3362222 ,
#        -1.37625   ,  2.1701014 ,  3.490825  ,  1.2169503 , -2.182879  ,
#        -1.7643021 ,  1.3065034 ,  1.330262  ,  2.4659514 ,  0.9330565 ,
#        -2.4665194 ,  3.377169  ,  0.33836058, -0.5541902 , -3.8452423 ,
#        -0.3124359 , -2.0320914 ,  1.4616188 , -1.9640503 , -3.2646942 ,
#        -1.667808  , -2.0543818 , -2.738596  , -3.4512625 , -0.95460224,
#        -0.11959687,  0.4203614 ,  0.40569404,  1.7514064 , -0.9041908 ,
#        -0.226651  ,  3.606256  ,  0.16846865,  3.7403173 , -0.02663359,
#        -0.22775728, -1.4472028 ,  0.90475196,  2.2600625 , -0.55276793,
#         0.93788695, -0.29716265, -1.0346454 , -0.49654147, -2.503171  ,
#         0.4593211 ,  3.5401633 ,  1.3159603 ,  0.5893555 , -0.20658031,
#         1.3657901 , -2.2225819 ,  2.4869845 , -1.4070765 ,  3.491437  ,
#        -0.6216417 ,  2.1309469 ,  2.762802  ,  2.4068487 , -0.14295815,
#         4.605627  , -0.7099847 , -1.4846077 , -1.184973  ,  0.58893704,
#        -0.90108603, -2.1814375 ,  1.6161324 , -0.33688962,  2.3469918 ],
#       dtype=float32)

# %%
train_vectors = features_embeddings_trained(train_tokenized_corpus)
print(len(train_vectors))
train_vectors[0].shape
# Out:
# 2010
# (300,)

# %%
test_vectors = features_embeddings_trained(test_tokenized_corpus)
print(len(test_vectors))
test_vectors[0].shape
# Out:
# 990
# (300,)

# %%
pd.DataFrame(train_vectors)
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.071765 -0.501332  0.266866 -0.539072  0.543804  0.260111  0.175274
# 1     0.201421 -0.835796  0.167064 -0.570961  0.463955  0.147549  0.522221
# 2     0.100804 -0.761593  0.050553 -0.359987  0.032850  0.450145 -0.044176
# 3    -0.059055 -0.613561 -0.352019 -0.197341  0.321426 -0.136975  0.484984
# 4    -0.247734 -0.122627 -0.234251  0.113897  0.412909  0.203975  0.196843
# ...        ...       ...       ...       ...       ...       ...       ...
# 2005  0.145286 -0.660611  0.096615  0.059080  0.418366 -0.048677  0.231591
# 2006 -0.132375  0.007622 -0.060736 -0.169088 -0.065853 -0.240801 -0.004792
# 2007  0.061875 -0.504767  0.128449 -0.309454  0.239758  0.448429  0.053110
# 2008  0.481774 -0.456385  0.371910 -0.351619  0.140414  0.081677  0.249063
# 2009  0.090497 -0.427850 -0.135858  0.034596  0.162196  0.173130  0.077221
#
#            7         8         9    ...       290       291       292  \
# 0    -0.025657  0.591547 -0.472240  ...  0.123862 -0.184058 -0.063175
# 1    -0.085878  0.511895 -0.483975  ...  0.113176 -0.324834 -0.197113
# 2    -0.275377  0.272777 -0.240959  ...  0.334790 -0.360708  0.444338
# 3    -0.339944  0.397234 -0.211405  ...  0.324440 -0.049765 -0.042620
# 4     0.114238 -0.100210  0.260022  ...  0.590531 -0.380305 -0.021766
# ...        ...       ...       ...  ...       ...       ...       ...
# 2005 -0.360000  0.168896  0.012134  ...  0.323186  0.065004 -0.259029
# 2006 -0.474806  0.204424 -0.280626  ...  0.336286 -0.373046 -0.101730
# 2007 -0.022847  0.268978 -0.157851  ...  0.119790 -0.248116  0.137337
# 2008 -0.453577  0.048269 -0.103956  ... -0.006385 -0.106864 -0.074057
# 2009  0.105850  0.017096 -0.203091  ...  0.327679 -0.256625 -0.110307
#
#            293       294       295       296       297       298       299
# 0     1.502401  0.105758  0.561694  0.195198 -0.154106 -0.705223  0.553513
# 1     1.404224  0.185555  0.433111  0.254629  0.201344 -0.938394  0.258309
# 2     0.911963 -0.183864  0.532553  0.163177  0.660180 -0.567780  0.196322
# 3     0.549133  0.031745  0.500848  0.243917  0.154506 -0.393167  0.501330
# 4     0.510044 -0.107208  0.132068 -0.025983  0.021583  0.103656  0.356382
# ...        ...       ...       ...       ...       ...       ...       ...
# 2005  1.012612 -0.184087  0.426128  0.422127  0.025579 -0.266824 -0.152251
# 2006  0.558735  0.085740  0.723193  0.238508  0.306485 -0.265801  0.111616
# 2007  0.471121 -0.248154  0.209134  0.027269  0.123677 -0.271872  0.236434
# 2008  0.126658 -0.418518  0.317682  0.147618  0.253540 -0.325074 -0.163294
# 2009  0.808485 -0.455304  0.315116  0.066056  0.077143 -0.345132  0.177106
#
# [2010 rows x 300 columns]

# %%
model = LogisticRegression()

# %%
model.fit(train_vectors, train_y)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
train_pred = model.predict(train_vectors)
test_pred = model.predict(test_vectors)

# %%
confusion_matrix(train_y, train_pred)
# Out:
# array([[917, 115],
#        [110, 868]])

# %%
confusion_matrix(test_y, test_pred)
# Out:
# array([[403,  91],
#        [113, 383]])

# %%
print("Train Accuracy : ",accuracy_score(train_y, train_pred))
print("Test Accuracy : ",accuracy_score(test_y, test_pred))
# Out:
# Train Accuracy :  0.8880597014925373
# Test Accuracy :  0.793939393939394

# %% [markdown]
# # Fasttext Pre trained

# %%
import fasttext.util
fasttext.util.download_model('en', if_exists='ignore')  # English
ft = fasttext.load_model('cc.en.300.bin')

# %%
ft.save_model('cc.en.100.bin')

# %%
ft.get_dimension()
# Out:
# 300

# %%
ft.get_word_vector('good')
# Out:
# array([-0.09213716, -0.0634383 ,  0.00173813,  0.13524324, -0.06561062,
#         0.00619071,  0.12609869, -0.01646539,  0.0174491 , -0.00126792,
#        -0.09709831,  0.02329333,  0.00996784,  0.00463419,  0.01587938,
#         0.00689824,  0.08575399, -0.01988525, -0.0601579 , -0.02327966,
#         0.01183712,  0.08217917,  0.01488847,  0.00902181,  0.00696296,
#        -0.06426616,  0.03345198, -0.02101481,  0.06767873,  0.03022419,
#         0.07203474, -0.05689922, -0.04370377,  0.00642597,  0.0439174 ,
#         0.0604848 , -0.00611545, -0.12256738, -0.03530414, -0.02696739,
#        -0.02058216,  0.00752347, -0.00686451,  0.0362783 , -0.03308735,
#         0.05801626,  0.00832448, -0.06336953, -0.05775082,  0.01089846,
#        -0.0925179 ,  0.01559984, -0.04079024,  0.0066871 , -0.06374165,
#         0.05881973,  0.07209535, -0.05387195, -0.14658651, -0.04046486,
#        -0.02507038, -0.04954465, -0.05224417, -0.06846938,  0.0467079 ,
#         0.00459271, -0.07522177,  0.03627685, -0.0698283 ,  0.0174791 ,
#        -0.03427085, -0.043176  ,  0.00764059,  0.05694873,  0.0064466 ,
#        -0.01078498,  0.02328758,  0.06951396,  0.05373847,  0.02533235,
#         0.04307906, -0.03298698, -0.01265992,  0.02883131,  0.01145704,
#        -0.03029559,  0.02814867,  0.09258693,  0.08908885,  0.21924517,
#         0.03836972,  0.05020344,  0.13716629, -0.00859585, -0.0113667 ,
#         0.10641211, -0.07889125,  0.08034115, -0.00441031, -0.04873084,
#         0.00183913,  0.06675661,  0.00995041,  0.03010932, -0.02987454,
#         0.02509423, -0.04333989, -0.0059728 , -0.00332469, -0.0522663 ,
#        -0.03281598,  0.12006998,  0.01166376, -0.03454734,  0.01907663,
#        -0.01262398, -0.02025696,  0.01866139,  0.05016267,  0.05604192,
#         0.04971652,  0.03597424, -0.00690809,  0.05734055,  0.05945349,
#         0.0261135 ,  0.01734888, -0.00711455, -0.1295353 ,  0.01600225,
#         0.00150194, -0.03631282, -0.00469453,  0.02215887, -0.00699799,
#        -0.02894606,  0.03908806,  0.0401371 , -0.03941151, -0.02646147,
#        -0.04718655,  0.02674983,  0.07485171,  0.03144611, -0.07028159,
#        -0.0424196 , -0.2054326 , -0.09083363, -0.01121964,  0.05520659,
#        -0.11916859,  0.00788128, -0.13444994, -0.01488061, -0.02091767,
#         0.09262317,  0.06291065, -0.02200251, -0.03655258,  0.02587264,
#         0.0447952 , -0.01287306, -0.0350248 , -0.02456109, -0.04746678,
#         0.00130645,  0.01147217, -0.00531678,  0.11162786,  0.0253936 ,
#        -0.03638908, -0.05931935, -0.00549408,  0.0074574 , -0.01289796,
#        -0.0719263 , -0.02486867, -0.04750141,  0.00194147, -0.1141203 ,
#         0.01648522,  0.05083858, -0.02679086, -0.04766015,  0.00518819,
#         0.04099732,  0.02709844, -0.06511603, -0.06652133, -0.07979076,
#         0.0491582 ,  0.05377757,  0.0200878 , -0.03799915, -0.02513728,
#         0.00410288, -0.04514588, -0.04708159, -0.00559349,  0.13073431,
#        -0.09549722,  0.16606593,  0.0221815 , -0.05887613, -0.02126267,
#         0.00425452, -0.05540022, -0.06286709, -0.05455609,  0.11610305,
#         0.12443443, -0.00741135,  0.01761745, -0.0075937 , -0.05616794,
#        -0.01676267,  0.07975771, -0.04046471,  0.07211975,  0.13321361,
#         0.07106   , -0.01443719,  0.02562447,  0.05690589, -0.0090815 ,
#        -0.00628489,  0.03647495,  0.00689165,  0.04463093,  0.01837448,
#         0.00218417, -0.02093561,  0.07896647, -0.05610979,  0.02535573,
#        -0.09674191, -0.03684152,  0.01628419,  0.00908958, -0.06135098,
#         0.05458912, -0.03850613,  0.03017449, -0.1417458 ,  0.17130415,
#        -0.05436675, -0.01079106,  0.04692602, -0.02894384, -0.0273016 ,
#         0.09735578, -0.13424474, -0.02024667, -0.04736632, -0.03244197,
#         0.00541304, -0.04343438, -0.0003211 ,  0.16816942,  0.03105447,
#        -0.03063404, -0.00045107,  0.04690041,  0.11270425, -0.13718411,
#         0.05740229,  0.00801181, -0.17329559,  0.03051268, -0.1268264 ,
#        -0.06074513, -0.03838078, -0.01737073,  0.12296247, -0.05316308,
#        -0.07613882,  0.02129988,  0.0121702 , -0.01287838,  0.0768657 ,
#        -0.26769733,  0.05321693, -0.12607867, -0.02812696,  0.07982896,
#        -0.02915069, -0.01767069, -0.10350563, -0.0471432 , -0.03033449,
#         0.08542065,  0.02928957, -0.11185424, -0.00142424,  0.0379483 ,
#         0.02438426, -0.01398861,  0.14165413, -0.05115522, -0.08859383],
#       dtype=float32)

# %%
# Creating a feature vector by averaging all embeddings for all sentences
def features_embeddings_pretrained_fasttext(w2v_model, list_of_lists):
    
    # feature vector column length 
    DIMENSION = w2v_model.get_dimension()
    
    # Zero vector if words not in our w2v_model vocubulary
    zero_vector = np.zeros(DIMENSION)
    
    features = []
    
    # feature vector for each sentence in list_of_lists one by one
    for tokens in list_of_lists:
        
        # feature vector for a single sentence
        feature =  np.zeros(DIMENSION) # shape = 1X DIMENSION
        
        # count for each token/word in a tokens or sentence
        feature_counts = 0 + 1e-5   # to avoid divide-by-zero 
        for token in tokens:
            feature += w2v_model.get_word_vector(token) # Here both feature and w2v_model[token] are of same shape : 1X DIMENSION
            feature_counts +=1    # Count increases for each token in a tokens
         
        # Average the feature values for each tokens
        if(feature_counts !=0 ):        # for non empty tokens
            features.append(feature/feature_counts) 
        else:                           # for empty tokens
            features.append(zero_vector)     
    return features

# %%
train_vectors = features_embeddings_pretrained_fasttext(ft, train_tokenized_corpus)
print(len(train_vectors))
train_vectors[0].shape
# Out:
# 2010
# (300,)

# %%
test_vectors = features_embeddings_pretrained_fasttext(ft, test_tokenized_corpus)
print(len(test_vectors))
test_vectors[0].shape
# Out:
# 990
# (300,)

# %%
model = LogisticRegression()

# %%
model.fit(train_vectors, train_y)
# Out:
# LogisticRegression()

# %%
train_pred = model.predict(train_vectors)
test_pred = model.predict(test_vectors)

# %%
confusion_matrix(train_y, train_pred)
# Out:
# array([[834, 198],
#        [260, 718]])

# %%
confusion_matrix(test_y, test_pred)
# Out:
# array([[402,  92],
#        [143, 353]])

# %%
print("Train Accuracy : ",accuracy_score(train_y, train_pred))
print("Test Accuracy : ",accuracy_score(test_y, test_pred))
# Out:
# Train Accuracy :  0.7721393034825871
# Test Accuracy :  0.7626262626262627
